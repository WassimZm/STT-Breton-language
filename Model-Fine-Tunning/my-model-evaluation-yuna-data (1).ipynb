# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_23.wav
# /kaggle/input/dastum-test-data/test/350603_clip_413.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_16.wav
# /kaggle/input/dastum-test-data/test/350617_clip_112.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_177.wav
# /kaggle/input/dastum-test-data/test/350617_clip_373.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_66.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_455.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_363.wav
# /kaggle/input/dastum-test-data/test/350603_clip_61.wav
# /kaggle/input/dastum-test-data/test/350627_clip_467.wav
# /kaggle/input/dastum-test-data/test/350617_clip_16.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_460.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_541.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_792.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_180.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_167.wav
# /kaggle/input/dastum-test-data/test/350615_clip_107.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_123.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_1.wav
# /kaggle/input/dastum-test-data/test/350627_clip_471.wav
# /kaggle/input/dastum-test-data/test/350615_clip_720.wav
# /kaggle/input/dastum-test-data/test/350615_clip_462.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_329.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_117.wav
# /kaggle/input/dastum-test-data/test/350627_clip_393.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_266.wav
# /kaggle/input/dastum-test-data/test/350617_clip_335.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_875.wav
# /kaggle/input/dastum-test-data/test/350627_clip_489.wav
# /kaggle/input/dastum-test-data/test/350615_clip_622.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_253.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_268.wav
# /kaggle/input/dastum-test-data/test/350615_clip_999.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_69.wav
# /kaggle/input/dastum-test-data/test/350615_clip_822.wav
# /kaggle/input/dastum-test-data/test/350603_clip_640.wav
# /kaggle/input/dastum-test-data/test/350615_clip_64.wav
# /kaggle/input/dastum-test-data/test/350627_clip_900.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_53.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_469.wav
# /kaggle/input/dastum-test-data/test/350603_clip_651.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_467.wav
# /kaggle/input/dastum-test-data/test/350603_clip_327.wav
# /kaggle/input/dastum-test-data/test/350615_clip_601.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_49.wav
# /kaggle/input/dastum-test-data/test/350615_clip_582.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_291.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_666.wav
# /kaggle/input/dastum-test-data/test/350615_clip_200.wav
# /kaggle/input/dastum-test-data/test/350627_clip_110.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_15.wav
# /kaggle/input/dastum-test-data/test/350615_clip_464.wav
# /kaggle/input/dastum-test-data/test/350627_clip_543.wav
# /kaggle/input/dastum-test-data/test/350617_clip_635.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_191.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_120.wav
# /kaggle/input/dastum-test-data/test/350627_clip_465.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_4.wav
# /kaggle/input/dastum-test-data/test/350603_clip_738.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_288.wav
# /kaggle/input/dastum-test-data/test/350617_clip_187.wav
# /kaggle/input/dastum-test-data/test/350627_clip_262.wav
# /kaggle/input/dastum-test-data/test/350615_clip_320.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_255.wav
# /kaggle/input/dastum-test-data/test/350627_clip_325.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_104.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_177.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_271.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_124.wav
# /kaggle/input/dastum-test-data/test/350627_clip_341.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_326.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1020.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_331.wav
# /kaggle/input/dastum-test-data/test/350615_clip_228.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1039.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_269.wav
# /kaggle/input/dastum-test-data/test/350617_clip_848.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_19.wav
# /kaggle/input/dastum-test-data/test/350617_clip_238.wav
# /kaggle/input/dastum-test-data/test/350603_clip_469.wav
# /kaggle/input/dastum-test-data/test/350617_clip_239.wav
# /kaggle/input/dastum-test-data/test/350615_clip_51.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1046.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_355.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_180.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_364.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_159.wav
# /kaggle/input/dastum-test-data/test/350627_clip_257.wav
# /kaggle/input/dastum-test-data/test/350615_clip_380.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_112.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_72.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_91.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_485.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_315.wav
# /kaggle/input/dastum-test-data/test/350627_clip_645.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_24.wav
# /kaggle/input/dastum-test-data/test/350627_clip_8.wav
# /kaggle/input/dastum-test-data/test/350617_clip_167.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_691.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_87.wav
# /kaggle/input/dastum-test-data/test/350617_clip_35.wav
# /kaggle/input/dastum-test-data/test/350617_clip_517.wav
# /kaggle/input/dastum-test-data/test/350617_clip_369.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_722.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_0.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_290.wav
# /kaggle/input/dastum-test-data/test/350627_clip_404.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_634.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_148.wav
# /kaggle/input/dastum-test-data/test/350615_clip_363.wav
# /kaggle/input/dastum-test-data/test/350615_clip_299.wav
# /kaggle/input/dastum-test-data/test/350627_clip_675.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_43.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1043.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_1.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_500.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_96.wav
# /kaggle/input/dastum-test-data/test/350603_clip_513.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_387.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_232.wav
# /kaggle/input/dastum-test-data/test/350627_clip_492.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_231.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_561.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_42.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_202.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_91.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_445.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_4.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_4.wav
# /kaggle/input/dastum-test-data/test/350603_clip_784.wav
# /kaggle/input/dastum-test-data/test/350627_clip_188.wav
# /kaggle/input/dastum-test-data/test/350617_clip_841.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_38.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_93.wav
# /kaggle/input/dastum-test-data/test/350615_clip_98.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_687.wav
# /kaggle/input/dastum-test-data/test/350627_clip_639.wav
# /kaggle/input/dastum-test-data/test/350603_clip_790.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_100.wav
# /kaggle/input/dastum-test-data/test/350615_clip_792.wav
# /kaggle/input/dastum-test-data/test/350603_clip_9.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_166.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1106.wav
# /kaggle/input/dastum-test-data/test/350615_clip_203.wav
# /kaggle/input/dastum-test-data/test/350617_clip_527.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_897.wav
# /kaggle/input/dastum-test-data/test/350617_clip_354.wav
# /kaggle/input/dastum-test-data/test/350627_clip_919.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_130.wav
# /kaggle/input/dastum-test-data/test/350615_clip_16.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_554.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_579.wav
# /kaggle/input/dastum-test-data/test/350615_clip_386.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_303.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_62.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_290.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_699.wav
# /kaggle/input/dastum-test-data/test/350615_clip_378.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_115.wav
# /kaggle/input/dastum-test-data/test/350627_clip_761.wav
# /kaggle/input/dastum-test-data/test/350627_clip_68.wav
# /kaggle/input/dastum-test-data/test/350615_clip_365.wav
# /kaggle/input/dastum-test-data/test/350603_clip_642.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_51.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_322.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_30.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_42.wav
# /kaggle/input/dastum-test-data/test/350617_clip_336.wav
# /kaggle/input/dastum-test-data/test/350603_clip_825.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_616.wav
# /kaggle/input/dastum-test-data/test/350615_clip_773.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_280.wav
# /kaggle/input/dastum-test-data/test/350603_clip_731.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_516.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_397.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_47.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_501.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_58.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_345.wav
# /kaggle/input/dastum-test-data/test/350615_clip_257.wav
# /kaggle/input/dastum-test-data/test/350615_clip_298.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_822.wav
# /kaggle/input/dastum-test-data/test/350603_clip_377.wav
# /kaggle/input/dastum-test-data/test/350627_clip_154.wav
# /kaggle/input/dastum-test-data/test/350627_clip_425.wav
# /kaggle/input/dastum-test-data/test/350617_clip_690.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_816.wav
# /kaggle/input/dastum-test-data/test/350617_clip_131.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_59.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_694.wav
# /kaggle/input/dastum-test-data/test/350615_clip_474.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_116.wav
# /kaggle/input/dastum-test-data/test/350615_clip_820.wav
# /kaggle/input/dastum-test-data/test/350627_clip_73.wav
# /kaggle/input/dastum-test-data/test/350603_clip_439.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_35.wav
# /kaggle/input/dastum-test-data/test/350617_clip_311.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_357.wav
# /kaggle/input/dastum-test-data/test/350617_clip_769.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_246.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_68.wav
# /kaggle/input/dastum-test-data/test/350603_clip_458.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_274.wav
# /kaggle/input/dastum-test-data/test/350615_clip_581.wav
# /kaggle/input/dastum-test-data/test/350627_clip_264.wav
# /kaggle/input/dastum-test-data/test/350603_clip_531.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_427.wav
# /kaggle/input/dastum-test-data/test/350627_clip_361.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_260.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_134.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1000.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_350.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_249.wav
# /kaggle/input/dastum-test-data/test/350615_clip_281.wav
# /kaggle/input/dastum-test-data/test/350615_clip_124.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_597.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_59.wav
# /kaggle/input/dastum-test-data/test/350615_clip_604.wav
# /kaggle/input/dastum-test-data/test/350603_clip_330.wav
# /kaggle/input/dastum-test-data/test/350617_clip_115.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_512.wav
# /kaggle/input/dastum-test-data/test/350627_clip_660.wav
# /kaggle/input/dastum-test-data/test/350617_clip_327.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_688.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_364.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_232.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_332.wav
# /kaggle/input/dastum-test-data/test/350615_clip_834.wav
# /kaggle/input/dastum-test-data/test/350617_clip_340.wav
# /kaggle/input/dastum-test-data/test/350603_clip_10.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_48.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_560.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_12.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_25.wav
# /kaggle/input/dastum-test-data/test/350615_clip_731.wav
# /kaggle/input/dastum-test-data/test/350617_clip_132.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_613.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_471.wav
# /kaggle/input/dastum-test-data/test/350615_clip_478.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_261.wav
# /kaggle/input/dastum-test-data/test/350603_clip_812.wav
# /kaggle/input/dastum-test-data/test/350627_clip_634.wav
# /kaggle/input/dastum-test-data/test/350627_clip_91.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_13.wav
# /kaggle/input/dastum-test-data/test/350627_clip_984.wav
# /kaggle/input/dastum-test-data/test/350617_clip_799.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1033.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_132.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_343.wav
# /kaggle/input/dastum-test-data/test/350627_clip_27.wav
# /kaggle/input/dastum-test-data/test/350615_clip_296.wav
# /kaggle/input/dastum-test-data/test/350627_clip_430.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_333.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1015.wav
# /kaggle/input/dastum-test-data/test/350603_clip_371.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1049.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_219.wav
# /kaggle/input/dastum-test-data/test/350615_clip_830.wav
# /kaggle/input/dastum-test-data/test/350617_clip_400.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_903.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_288.wav
# /kaggle/input/dastum-test-data/test/350615_clip_128.wav
# /kaggle/input/dastum-test-data/test/350615_clip_764.wav
# /kaggle/input/dastum-test-data/test/350627_clip_689.wav
# /kaggle/input/dastum-test-data/test/350615_clip_284.wav
# /kaggle/input/dastum-test-data/test/350615_clip_134.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_573.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_229.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_9.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_137.wav
# /kaggle/input/dastum-test-data/test/350615_clip_374.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_126.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_373.wav
# /kaggle/input/dastum-test-data/test/350603_clip_96.wav
# /kaggle/input/dastum-test-data/test/350615_clip_69.wav
# /kaggle/input/dastum-test-data/test/350615_clip_526.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_277.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_148.wav
# /kaggle/input/dastum-test-data/test/350603_clip_687.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_235.wav
# /kaggle/input/dastum-test-data/test/350627_clip_279.wav
# /kaggle/input/dastum-test-data/test/350627_clip_759.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_273.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_686.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_10.wav
# /kaggle/input/dastum-test-data/test/350615_clip_947.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_154.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1075.wav
# /kaggle/input/dastum-test-data/test/350617_clip_491.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_910.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_359.wav
# /kaggle/input/dastum-test-data/test/350603_clip_187.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_719.wav
# /kaggle/input/dastum-test-data/test/350615_clip_81.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_502.wav
# /kaggle/input/dastum-test-data/test/350627_clip_708.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_40.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_197.wav
# /kaggle/input/dastum-test-data/test/350603_clip_586.wav
# /kaggle/input/dastum-test-data/test/350603_clip_262.wav
# /kaggle/input/dastum-test-data/test/350627_clip_518.wav
# /kaggle/input/dastum-test-data/test/350603_clip_453.wav
# /kaggle/input/dastum-test-data/test/350615_clip_646.wav
# /kaggle/input/dastum-test-data/test/350603_clip_419.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_493.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1071.wav
# /kaggle/input/dastum-test-data/test/350617_clip_460.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_476.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_477.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_147.wav
# /kaggle/input/dastum-test-data/test/350615_clip_612.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_193.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_63.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_648.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_267.wav
# /kaggle/input/dastum-test-data/test/350603_clip_163.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_693.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_0.wav
# /kaggle/input/dastum-test-data/test/350603_clip_301.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_872.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_233.wav
# /kaggle/input/dastum-test-data/test/350603_clip_185.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_599.wav
# /kaggle/input/dastum-test-data/test/350627_clip_702.wav
# /kaggle/input/dastum-test-data/test/350627_clip_415.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1031.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_7.wav
# /kaggle/input/dastum-test-data/test/350603_clip_441.wav
# /kaggle/input/dastum-test-data/test/350627_clip_290.wav
# /kaggle/input/dastum-test-data/test/350617_clip_554.wav
# /kaggle/input/dastum-test-data/test/350617_clip_448.wav
# /kaggle/input/dastum-test-data/test/350627_clip_586.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_524.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_44.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_116.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_396.wav
# /kaggle/input/dastum-test-data/test/350627_clip_942.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_295.wav
# /kaggle/input/dastum-test-data/test/350615_clip_964.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_55.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_72.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_62.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_136.wav
# /kaggle/input/dastum-test-data/test/350603_clip_672.wav
# /kaggle/input/dastum-test-data/test/350615_clip_28.wav
# /kaggle/input/dastum-test-data/test/350603_clip_218.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_226.wav
# /kaggle/input/dastum-test-data/test/350603_clip_499.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_719.wav
# /kaggle/input/dastum-test-data/test/350615_clip_19.wav
# /kaggle/input/dastum-test-data/test/350603_clip_147.wav
# /kaggle/input/dastum-test-data/test/350627_clip_87.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_645.wav
# /kaggle/input/dastum-test-data/test/350627_clip_522.wav
# /kaggle/input/dastum-test-data/test/350627_clip_714.wav
# /kaggle/input/dastum-test-data/test/350615_clip_368.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_301.wav
# /kaggle/input/dastum-test-data/test/350617_clip_667.wav
# /kaggle/input/dastum-test-data/test/350627_clip_391.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_67.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_0.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_39.wav
# /kaggle/input/dastum-test-data/test/350615_clip_566.wav
# /kaggle/input/dastum-test-data/test/350615_clip_884.wav
# /kaggle/input/dastum-test-data/test/350615_clip_195.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_41.wav
# /kaggle/input/dastum-test-data/test/350603_clip_107.wav
# /kaggle/input/dastum-test-data/test/350627_clip_661.wav
# /kaggle/input/dastum-test-data/test/350627_clip_997.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_92.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1040.wav
# /kaggle/input/dastum-test-data/test/350627_clip_88.wav
# /kaggle/input/dastum-test-data/test/350603_clip_794.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_143.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_96.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_200.wav
# /kaggle/input/dastum-test-data/test/350627_clip_560.wav
# /kaggle/input/dastum-test-data/test/350617_clip_266.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_472.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_556.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_19.wav
# /kaggle/input/dastum-test-data/test/350615_clip_43.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_552.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_359.wav
# /kaggle/input/dastum-test-data/test/350627_clip_698.wav
# /kaggle/input/dastum-test-data/test/350603_clip_455.wav
# /kaggle/input/dastum-test-data/test/350603_clip_385.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_141.wav
# /kaggle/input/dastum-test-data/test/350615_clip_225.wav
# /kaggle/input/dastum-test-data/test/350603_clip_721.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_340.wav
# /kaggle/input/dastum-test-data/test/350627_clip_715.wav
# /kaggle/input/dastum-test-data/test/350603_clip_572.wav
# /kaggle/input/dastum-test-data/test/350603_clip_667.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_171.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_302.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_703.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_187.wav
# /kaggle/input/dastum-test-data/test/350615_clip_920.wav
# /kaggle/input/dastum-test-data/test/350627_clip_101.wav
# /kaggle/input/dastum-test-data/test/350617_clip_814.wav
# /kaggle/input/dastum-test-data/test/350603_clip_402.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_13.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_118.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_653.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_55.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_725.wav
# /kaggle/input/dastum-test-data/test/350603_clip_83.wav
# /kaggle/input/dastum-test-data/test/350627_clip_886.wav
# /kaggle/input/dastum-test-data/test/350615_clip_851.wav
# /kaggle/input/dastum-test-data/test/350627_clip_520.wav
# /kaggle/input/dastum-test-data/test/350615_clip_891.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_133.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_39.wav
# /kaggle/input/dastum-test-data/test/350627_clip_600.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_748.wav
# /kaggle/input/dastum-test-data/test/350617_clip_523.wav
# /kaggle/input/dastum-test-data/test/350615_clip_805.wav
# /kaggle/input/dastum-test-data/test/350615_clip_313.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_248.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1001.wav
# /kaggle/input/dastum-test-data/test/350603_clip_575.wav
# /kaggle/input/dastum-test-data/test/350603_clip_592.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_202.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_113.wav
# /kaggle/input/dastum-test-data/test/350627_clip_265.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_266.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_281.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_709.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_661.wav
# /kaggle/input/dastum-test-data/test/350603_clip_286.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_561.wav
# /kaggle/input/dastum-test-data/test/350617_clip_472.wav
# /kaggle/input/dastum-test-data/test/350603_clip_347.wav
# /kaggle/input/dastum-test-data/test/350617_clip_198.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_19.wav
# /kaggle/input/dastum-test-data/test/350615_clip_233.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_332.wav
# /kaggle/input/dastum-test-data/test/350615_clip_316.wav
# /kaggle/input/dastum-test-data/test/350617_clip_668.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_434.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_227.wav
# /kaggle/input/dastum-test-data/test/350615_clip_868.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1067.wav
# /kaggle/input/dastum-test-data/test/350615_clip_616.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_93.wav
# /kaggle/input/dastum-test-data/test/350627_clip_563.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_387.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_238.wav
# /kaggle/input/dastum-test-data/test/350603_clip_112.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_412.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_106.wav
# /kaggle/input/dastum-test-data/test/350615_clip_265.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_206.wav
# /kaggle/input/dastum-test-data/test/350617_clip_46.wav
# /kaggle/input/dastum-test-data/test/350603_clip_42.wav
# /kaggle/input/dastum-test-data/test/350603_clip_379.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_445.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_7.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_390.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_69.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_168.wav
# /kaggle/input/dastum-test-data/test/350615_clip_924.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_74.wav
# /kaggle/input/dastum-test-data/test/350615_clip_708.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_692.wav
# /kaggle/input/dastum-test-data/test/350615_clip_800.wav
# /kaggle/input/dastum-test-data/test/350617_clip_49.wav
# /kaggle/input/dastum-test-data/test/350617_clip_29.wav
# /kaggle/input/dastum-test-data/test/350615_clip_879.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_318.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_151.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_540.wav
# /kaggle/input/dastum-test-data/test/350603_clip_144.wav
# /kaggle/input/dastum-test-data/test/350615_clip_815.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_34.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_75.wav
# /kaggle/input/dastum-test-data/test/350617_clip_218.wav
# /kaggle/input/dastum-test-data/test/350617_clip_113.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_509.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_577.wav
# /kaggle/input/dastum-test-data/test/350615_clip_293.wav
# /kaggle/input/dastum-test-data/test/350615_clip_44.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_73.wav
# /kaggle/input/dastum-test-data/test/350617_clip_556.wav
# /kaggle/input/dastum-test-data/test/350627_clip_703.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_492.wav
# /kaggle/input/dastum-test-data/test/350617_clip_826.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_547.wav
# /kaggle/input/dastum-test-data/test/350615_clip_586.wav
# /kaggle/input/dastum-test-data/test/350627_clip_508.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_258.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_358.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_82.wav
# /kaggle/input/dastum-test-data/test/350603_clip_1158.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_281.wav
# /kaggle/input/dastum-test-data/test/350615_clip_477.wav
# /kaggle/input/dastum-test-data/test/350615_clip_484.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_855.wav
# /kaggle/input/dastum-test-data/test/350603_clip_561.wav
# /kaggle/input/dastum-test-data/test/350627_clip_398.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_363.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_75.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1058.wav
# /kaggle/input/dastum-test-data/test/350617_clip_743.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_19.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_111.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_670.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_405.wav
# /kaggle/input/dastum-test-data/test/350617_clip_13.wav
# /kaggle/input/dastum-test-data/test/350615_clip_961.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_327.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_54.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_60.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_74.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_126.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_82.wav
# /kaggle/input/dastum-test-data/test/350615_clip_206.wav
# /kaggle/input/dastum-test-data/test/350627_clip_417.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_714.wav
# /kaggle/input/dastum-test-data/test/350615_clip_66.wav
# /kaggle/input/dastum-test-data/test/350615_clip_176.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_184.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_62.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_905.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_26.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_46.wav
# /kaggle/input/dastum-test-data/test/350603_clip_74.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_902.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_104.wav
# /kaggle/input/dastum-test-data/test/350627_clip_669.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_572.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_82.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_171.wav
# /kaggle/input/dastum-test-data/test/350615_clip_911.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_6.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_439.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_60.wav
# /kaggle/input/dastum-test-data/test/350615_clip_600.wav
# /kaggle/input/dastum-test-data/test/350617_clip_334.wav
# /kaggle/input/dastum-test-data/test/350615_clip_657.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_17.wav
# /kaggle/input/dastum-test-data/test/350617_clip_492.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_123.wav
# /kaggle/input/dastum-test-data/test/350617_clip_375.wav
# /kaggle/input/dastum-test-data/test/350617_clip_526.wav
# /kaggle/input/dastum-test-data/test/350617_clip_641.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_205.wav
# /kaggle/input/dastum-test-data/test/350603_clip_324.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_35.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_116.wav
# /kaggle/input/dastum-test-data/test/350615_clip_336.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_296.wav
# /kaggle/input/dastum-test-data/test/350617_clip_109.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_118.wav
# /kaggle/input/dastum-test-data/test/350617_clip_384.wav
# /kaggle/input/dastum-test-data/test/350627_clip_114.wav
# /kaggle/input/dastum-test-data/test/350615_clip_756.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_805.wav
# /kaggle/input/dastum-test-data/test/350615_clip_897.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_73.wav
# /kaggle/input/dastum-test-data/test/350617_clip_626.wav
# /kaggle/input/dastum-test-data/test/350627_clip_958.wav
# /kaggle/input/dastum-test-data/test/350617_clip_106.wav
# /kaggle/input/dastum-test-data/test/350603_clip_447.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_576.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_551.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_335.wav
# /kaggle/input/dastum-test-data/test/350627_clip_611.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_398.wav
# /kaggle/input/dastum-test-data/test/350615_clip_649.wav
# /kaggle/input/dastum-test-data/test/350617_clip_331.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_633.wav
# /kaggle/input/dastum-test-data/test/350603_clip_820.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_43.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_474.wav
# /kaggle/input/dastum-test-data/test/350615_clip_750.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_167.wav
# /kaggle/input/dastum-test-data/test/350627_clip_554.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_46.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_352.wav
# /kaggle/input/dastum-test-data/test/350627_clip_674.wav
# /kaggle/input/dastum-test-data/test/350603_clip_100.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_6.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_114.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_696.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_42.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_154.wav
# /kaggle/input/dastum-test-data/test/350617_clip_271.wav
# /kaggle/input/dastum-test-data/test/350603_clip_543.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_262.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_59.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_172.wav
# /kaggle/input/dastum-test-data/test/350615_clip_987.wav
# /kaggle/input/dastum-test-data/test/350603_clip_210.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_88.wav
# /kaggle/input/dastum-test-data/test/350615_clip_883.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_215.wav
# /kaggle/input/dastum-test-data/test/350603_clip_559.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_483.wav
# /kaggle/input/dastum-test-data/test/350603_clip_158.wav
# /kaggle/input/dastum-test-data/test/350615_clip_869.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_391.wav
# /kaggle/input/dastum-test-data/test/350627_clip_548.wav
# /kaggle/input/dastum-test-data/test/350627_clip_444.wav
# /kaggle/input/dastum-test-data/test/350627_clip_655.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_352.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_199.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_184.wav
# /kaggle/input/dastum-test-data/test/350627_clip_303.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_222.wav
# /kaggle/input/dastum-test-data/test/350603_clip_148.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_298.wav
# /kaggle/input/dastum-test-data/test/350617_clip_72.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_7.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_88.wav
# /kaggle/input/dastum-test-data/test/350627_clip_26.wav
# /kaggle/input/dastum-test-data/test/350603_clip_617.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_158.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_194.wav
# /kaggle/input/dastum-test-data/test/350617_clip_732.wav
# /kaggle/input/dastum-test-data/test/350627_clip_339.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_453.wav
# /kaggle/input/dastum-test-data/test/350627_clip_637.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_258.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_241.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_486.wav
# /kaggle/input/dastum-test-data/test/350627_clip_701.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_682.wav
# /kaggle/input/dastum-test-data/test/350617_clip_580.wav
# /kaggle/input/dastum-test-data/test/350603_clip_120.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_223.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_404.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_376.wav
# /kaggle/input/dastum-test-data/test/350603_clip_541.wav
# /kaggle/input/dastum-test-data/test/350617_clip_692.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_529.wav
# /kaggle/input/dastum-test-data/test/350627_clip_234.wav
# /kaggle/input/dastum-test-data/test/350617_clip_585.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_196.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_14.wav
# /kaggle/input/dastum-test-data/test/350617_clip_299.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_98.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_159.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_156.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_38.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_244.wav
# /kaggle/input/dastum-test-data/test/350603_clip_621.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_670.wav
# /kaggle/input/dastum-test-data/test/350627_clip_223.wav
# /kaggle/input/dastum-test-data/test/350615_clip_240.wav
# /kaggle/input/dastum-test-data/test/350627_clip_493.wav
# /kaggle/input/dastum-test-data/test/350617_clip_825.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_406.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_227.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_58.wav
# /kaggle/input/dastum-test-data/test/350603_clip_797.wav
# /kaggle/input/dastum-test-data/test/350615_clip_279.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_108.wav
# /kaggle/input/dastum-test-data/test/350603_clip_23.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_323.wav
# /kaggle/input/dastum-test-data/test/350615_clip_747.wav
# /kaggle/input/dastum-test-data/test/350617_clip_454.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_609.wav
# /kaggle/input/dastum-test-data/test/350627_clip_308.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_679.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_356.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_116.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_106.wav
# /kaggle/input/dastum-test-data/test/350617_clip_306.wav
# /kaggle/input/dastum-test-data/test/350627_clip_210.wav
# /kaggle/input/dastum-test-data/test/350615_clip_390.wav
# /kaggle/input/dastum-test-data/test/350615_clip_613.wav
# /kaggle/input/dastum-test-data/test/350617_clip_504.wav
# /kaggle/input/dastum-test-data/test/350617_clip_413.wav
# /kaggle/input/dastum-test-data/test/350617_clip_485.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_56.wav
# /kaggle/input/dastum-test-data/test/350615_clip_7.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_500.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_108.wav
# /kaggle/input/dastum-test-data/test/350627_clip_991.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_831.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_528.wav
# /kaggle/input/dastum-test-data/test/350627_clip_94.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_464.wav
# /kaggle/input/dastum-test-data/test/350617_clip_738.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_57.wav
# /kaggle/input/dastum-test-data/test/350627_clip_372.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_78.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_124.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_212.wav
# /kaggle/input/dastum-test-data/test/350603_clip_579.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_568.wav
# /kaggle/input/dastum-test-data/test/350603_clip_622.wav
# /kaggle/input/dastum-test-data/test/350617_clip_25.wav
# /kaggle/input/dastum-test-data/test/350627_clip_910.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_930.wav
# /kaggle/input/dastum-test-data/test/350615_clip_229.wav
# /kaggle/input/dastum-test-data/test/350627_clip_682.wav
# /kaggle/input/dastum-test-data/test/350603_clip_66.wav
# /kaggle/input/dastum-test-data/test/350615_clip_575.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_87.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1090.wav
# /kaggle/input/dastum-test-data/test/350603_clip_328.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_311.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_12.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_140.wav
# /kaggle/input/dastum-test-data/test/350617_clip_502.wav
# /kaggle/input/dastum-test-data/test/350617_clip_768.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_49.wav
# /kaggle/input/dastum-test-data/test/350617_clip_760.wav
# /kaggle/input/dastum-test-data/test/350627_clip_525.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_351.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_106.wav
# /kaggle/input/dastum-test-data/test/350617_clip_782.wav
# /kaggle/input/dastum-test-data/test/350617_clip_214.wav
# /kaggle/input/dastum-test-data/test/350627_clip_512.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_411.wav
# /kaggle/input/dastum-test-data/test/350627_clip_668.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_333.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_327.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_698.wav
# /kaggle/input/dastum-test-data/test/350603_clip_180.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_141.wav
# /kaggle/input/dastum-test-data/test/350617_clip_845.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_106.wav
# /kaggle/input/dastum-test-data/test/350603_clip_135.wav
# /kaggle/input/dastum-test-data/test/350627_clip_742.wav
# /kaggle/input/dastum-test-data/test/350617_clip_366.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_36.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_48.wav
# /kaggle/input/dastum-test-data/test/350617_clip_757.wav
# /kaggle/input/dastum-test-data/test/350615_clip_757.wav
# /kaggle/input/dastum-test-data/test/350617_clip_658.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_210.wav
# /kaggle/input/dastum-test-data/test/350617_clip_649.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_737.wav
# /kaggle/input/dastum-test-data/test/350615_clip_542.wav
# /kaggle/input/dastum-test-data/test/350627_clip_187.wav
# /kaggle/input/dastum-test-data/test/350617_clip_813.wav
# /kaggle/input/dastum-test-data/test/350615_clip_350.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_433.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_139.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_506.wav
# /kaggle/input/dastum-test-data/test/350603_clip_830.wav
# /kaggle/input/dastum-test-data/test/350627_clip_379.wav
# /kaggle/input/dastum-test-data/test/350627_clip_51.wav
# /kaggle/input/dastum-test-data/test/350617_clip_553.wav
# /kaggle/input/dastum-test-data/test/350617_clip_861.wav
# /kaggle/input/dastum-test-data/test/350603_clip_94.wav
# /kaggle/input/dastum-test-data/test/350603_clip_51.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_138.wav
# ...
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_108.wav
# /kaggle/input/dastum-test-data/test/350617_clip_453.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_294.wav
# /kaggle/input/dastum-test-data/test/350617_clip_739.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_89.wav
# /kaggle/input/dastum-test-data/test/350615_clip_295.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_600.wav
# /kaggle/input/dastum-test-data/test/350615_clip_153.wav
# /kaggle/input/dastum-test-data/test/350627_clip_160.wav
# /kaggle/input/dastum-test-data/test/350603_clip_186.wav
# /kaggle/input/dastum-test-data/test/350615_clip_292.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_215.wav
# /kaggle/input/dastum-test-data/test/350617_clip_201.wav
# /kaggle/input/dastum-test-data/test/350615_clip_875.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1025.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_280.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_925.wav
# /kaggle/input/dastum-test-data/test/350617_clip_165.wav
# /kaggle/input/dastum-test-data/test/350603_clip_822.wav
# /kaggle/input/dastum-test-data/test/350627_clip_366.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_554.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_214.wav
# /kaggle/input/dastum-test-data/test/350627_clip_368.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_144.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_175.wav
# /kaggle/input/dastum-test-data/test/350617_clip_573.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_246.wav
# /kaggle/input/dastum-test-data/test/350617_clip_134.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_233.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_260.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_693.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_195.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_321.wav
# /kaggle/input/dastum-test-data/test/350617_clip_505.wav
# /kaggle/input/dastum-test-data/test/350615_clip_1048.wav
# /kaggle/input/dastum-test-data/test/350603_clip_733.wav
# /kaggle/input/dastum-test-data/test/350615_clip_94.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_287.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_583.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_171.wav
# /kaggle/input/dastum-test-data/test/350627_clip_35.wav
# /kaggle/input/dastum-test-data/test/350615_clip_9.wav
# /kaggle/input/dastum-test-data/test/350617_clip_40.wav
# /kaggle/input/dastum-test-data/test/350603_clip_626.wav
# /kaggle/input/dastum-test-data/test/350627_clip_435.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_336.wav
# /kaggle/input/dastum-test-data/test/350603_clip_646.wav
# /kaggle/input/dastum-test-data/test/350617_clip_607.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_234.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_129.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_222.wav
# /kaggle/input/dastum-test-data/test/350615_clip_194.wav
# /kaggle/input/dastum-test-data/test/350627_clip_256.wav
# /kaggle/input/dastum-test-data/test/350615_clip_856.wav
# /kaggle/input/dastum-test-data/test/350627_clip_70.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_182.wav
# /kaggle/input/dastum-test-data/test/350615_clip_804.wav
# /kaggle/input/dastum-test-data/test/350627_clip_752.wav
# /kaggle/input/dastum-test-data/test/350617_clip_296.wav
# /kaggle/input/dastum-test-data/test/350617_clip_376.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_507.wav
# /kaggle/input/dastum-test-data/test/350617_clip_800.wav
# /kaggle/input/dastum-test-data/test/350603_clip_1162.wav
# /kaggle/input/dastum-test-data/test/350627_clip_937.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_150.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_338.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_632.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_301.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_236.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_38.wav
# /kaggle/input/dastum-test-data/test/350617_clip_333.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_49.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_3.wav
# /kaggle/input/dastum-test-data/test/350603_clip_273.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_165.wav
# /kaggle/input/dastum-test-data/test/350617_clip_45.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_733.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_143.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_159.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_437.wav
# /kaggle/input/dastum-test-data/test/350615_clip_574.wav
# /kaggle/input/dastum-test-data/test/350615_clip_459.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_914.wav
# /kaggle/input/dastum-test-data/test/350615_clip_416.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_329.wav
# /kaggle/input/dastum-test-data/test/350615_clip_426.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_330.wav
# /kaggle/input/dastum-test-data/test/350615_clip_544.wav
# /kaggle/input/dastum-test-data/test/350603_clip_170.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_0.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_374.wav
# /kaggle/input/dastum-test-data/test/350615_clip_120.wav
# /kaggle/input/dastum-test-data/test/350603_clip_188.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_320.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_268.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_351.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_366.wav
# /kaggle/input/dastum-test-data/test/350627_clip_10.wav
# /kaggle/input/dastum-test-data/test/350615_clip_148.wav
# /kaggle/input/dastum-test-data/test/350615_clip_245.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_349.wav
# /kaggle/input/dastum-test-data/test/350615_clip_146.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_232.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_336.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_104.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_549.wav
# /kaggle/input/dastum-test-data/test/350627_clip_881.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_495.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_381.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_387.wav
# /kaggle/input/dastum-test-data/test/350627_clip_1000.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_233.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_343.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_355.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_26.wav
# /kaggle/input/dastum-test-data/test/350615_clip_684.wav
# /kaggle/input/dastum-test-data/test/350627_clip_589.wav
# /kaggle/input/dastum-test-data/test/350617_clip_124.wav
# /kaggle/input/dastum-test-data/test/350603_clip_357.wav
# /kaggle/input/dastum-test-data/test/350617_clip_60.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_105.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_399.wav
# /kaggle/input/dastum-test-data/test/350617_clip_387.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_346.wav
# /kaggle/input/dastum-test-data/test/350615_clip_718.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_586.wav
# /kaggle/input/dastum-test-data/test/350603_clip_722.wav
# /kaggle/input/dastum-test-data/test/350603_clip_827.wav
# /kaggle/input/dastum-test-data/test/350617_clip_362.wav
# /kaggle/input/dastum-test-data/test/350617_clip_620.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_705.wav
# /kaggle/input/dastum-test-data/test/350627_clip_920.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_739.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_528.wav
# /kaggle/input/dastum-test-data/test/350617_clip_278.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_335.wav
# /kaggle/input/dastum-test-data/test/350617_clip_128.wav
# /kaggle/input/dastum-test-data/test/350627_clip_342.wav
# /kaggle/input/dastum-test-data/test/350627_clip_901.wav
# /kaggle/input/dastum-test-data/test/350617_clip_289.wav
# /kaggle/input/dastum-test-data/test/350627_clip_67.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_564.wav
# /kaggle/input/dastum-test-data/test/350617_clip_292.wav
# /kaggle/input/dastum-test-data/test/350617_clip_171.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_268.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_16.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_35.wav
# /kaggle/input/dastum-test-data/test/350617_clip_416.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_352.wav
# /kaggle/input/dastum-test-data/test/350615_clip_795.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_368.wav
# /kaggle/input/dastum-test-data/test/350603_clip_681.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_470.wav
# /kaggle/input/dastum-test-data/test/350627_clip_464.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_59.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_217.wav
# /kaggle/input/dastum-test-data/test/350617_clip_619.wav
# /kaggle/input/dastum-test-data/test/350627_clip_902.wav
# /kaggle/input/dastum-test-data/test/350627_clip_335.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_130.wav
# /kaggle/input/dastum-test-data/test/350627_clip_352.wav
# /kaggle/input/dastum-test-data/test/350617_clip_839.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_315.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_177.wav
# /kaggle/input/dastum-test-data/test/350615_clip_449.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_52.wav
# /kaggle/input/dastum-test-data/test/350603_clip_250.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_502.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_10.wav
# /kaggle/input/dastum-test-data/test/350615_clip_709.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_562.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_334.wav
# /kaggle/input/dastum-test-data/test/350627_clip_385.wav
# /kaggle/input/dastum-test-data/test/350603_clip_600.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_417.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_160.wav
# /kaggle/input/dastum-test-data/test/350617_clip_210.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_141.wav
# /kaggle/input/dastum-test-data/test/350627_clip_245.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_582.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_161.wav
# /kaggle/input/dastum-test-data/test/350615_clip_858.wav
# /kaggle/input/dastum-test-data/test/350615_clip_529.wav
# /kaggle/input/dastum-test-data/test/350617_clip_682.wav
# /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_683.wav
# /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_28.wav
# /kaggle/input/dastum-test-data/test/350617_clip_315.wav
# /kaggle/input/dastum-test-data/test/350603_clip_707.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_207.wav
# /kaggle/input/dastum-test-data/test/350615_clip_954.wav
# /kaggle/input/dastum-test-data/test/350617_clip_141.wav
# /kaggle/input/dastum-test-data/test/350615_clip_658.wav
# /kaggle/input/dastum-test-data/test/350617_clip_617.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_158.wav
# /kaggle/input/dastum-test-data/test/350603_clip_95.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_198.wav
# /kaggle/input/dastum-test-data/test/350615_clip_307.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_557.wav
# /kaggle/input/dastum-test-data/test/350603_clip_397.wav
# /kaggle/input/dastum-test-data/test/350615_clip_833.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_361.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_221.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_703.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_1.wav
# /kaggle/input/dastum-test-data/test/350615_clip_481.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_641.wav
# /kaggle/input/dastum-test-data/test/350615_clip_927.wav
# /kaggle/input/dastum-test-data/test/350627_clip_591.wav
# /kaggle/input/dastum-test-data/test/350617_clip_188.wav
# /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_21.wav
# /kaggle/input/dastum-test-data/test/350615_clip_428.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_689.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_369.wav
# /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_667.wav
# /kaggle/input/transcriber-whisper/transcriber_whisper_fine_tuned.py
# /kaggle/input/scripts-codes/text/Whisper_Evaluation_small.ipynb
# /kaggle/input/scripts-codes/text/load_ground_truth_common_voice.py
# /kaggle/input/scripts-codes/text/definitions.py
# /kaggle/input/scripts-codes/text/Whisper_Evaluation_Base_Common_Voice.ipynb
# /kaggle/input/scripts-codes/text/wazemour@bocal.cs.univ-paris8.fr
# /kaggle/input/scripts-codes/text/Evaluation_Departement_Banque.ipynb
# /kaggle/input/scripts-codes/text/Whisper_Evaluation_tiny_2000.ipynb
# /kaggle/input/scripts-codes/text/normalizer.py
# /kaggle/input/scripts-codes/text/Whisper_Evaluation_base_2000.ipynb
# /kaggle/input/scripts-codes/text/filter_char.py
# /kaggle/input/scripts-codes/text/transcriber.py
# /kaggle/input/scripts-codes/text/gateway-bocal
# /kaggle/input/scripts-codes/text/utils.py
# /kaggle/input/scripts-codes/text/MP3toWAV.py
# /kaggle/input/scripts-codes/text/tokenizer.py
# /kaggle/input/scripts-codes/text/transcriber_whisper_old_model.py
# /kaggle/input/scripts-codes/text/load_ground_truth.py
# /kaggle/input/scripts-codes/text/Whisper_Evaluation_tiny.ipynb
# /kaggle/input/scripts-codes/text/evaluate_wer_cer.py
# /kaggle/input/scripts-codes/text/Replace_mp3_wav_in_file.py
# /kaggle/input/scripts-codes/text/CommonVoice_data_split.py
# /kaggle/input/scripts-codes/text/audio.py
# /kaggle/input/scripts-codes/text/Whisper_Evaluation_base.ipynb
# /kaggle/input/scripts-codes/text/dicts/corrected_tokens.tsv
# /kaggle/input/scripts-codes/text/dicts/first_names.tsv
# /kaggle/input/scripts-codes/text/dicts/proper_nouns_phon.tsv
# /kaggle/input/scripts-codes/text/dicts/named_entities.tsv
# /kaggle/input/scripts-codes/text/dicts/ipa.txt
# /kaggle/input/scripts-codes/text/dicts/places.tsv
# /kaggle/input/scripts-codes/text/dicts/gwenedeg_trad.tsv
# /kaggle/input/scripts-codes/text/dicts/abbreviations.tsv
# /kaggle/input/scripts-codes/text/dicts/last_names.tsv
# /kaggle/input/scripts-codes/text/dicts/acronyms.tsv
# /kaggle/input/scripts-codes/text/dicts/noun_f.tsv
# /kaggle/input/scripts-codes/text/dicts/adjectives.tsv
# /kaggle/input/scripts-codes/text/dicts/standard_tokens.tsv
# /kaggle/input/scripts-codes/text/dicts/stopwords.tsv
# /kaggle/input/scripts-codes/text/dicts/gwenedeg_peurunvan.tsv
# /kaggle/input/scripts-codes/text/dicts/interjections.tsv
# /kaggle/input/scripts-codes/text/dicts/sarmonioù_peurunvan.tsv
# /kaggle/input/scripts-codes/text/dicts/countries.tsv
# /kaggle/input/scripts-codes/text/dicts/__init__.py
# /kaggle/input/scripts-codes/text/dicts/noun_m.tsv

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.2.1)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.14.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 33.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-4.0.0 rapidfuzz-3.14.1

# %%
import os
import json
import jiwer

import sys

# %%
from datasets import load_dataset
import pandas as pd

dataset_name = "OuassimZm/Dastum-yar-stt-breton-data"

# %%
split = "test"  # or "train", "validation", etc.

# Load Hugging Face dataset
dataset = load_dataset(dataset_name, split=split)
# Out:
# README.md:   0%|          | 0.00/479 [00:00<?, ?B/s]
# data/train-00000-of-00004.parquet:   0%|          | 0.00/446M [00:00<?, ?B/s]
# data/train-00001-of-00004.parquet:   0%|          | 0.00/448M [00:00<?, ?B/s]
# data/train-00002-of-00004.parquet:   0%|          | 0.00/448M [00:00<?, ?B/s]
# data/train-00003-of-00004.parquet:   0%|          | 0.00/435M [00:00<?, ?B/s]
# data/test-00000-of-00002.parquet:   0%|          | 0.00/239M [00:00<?, ?B/s]
# data/test-00001-of-00002.parquet:   0%|          | 0.00/225M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6262 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1566 [00:00<?, ? examples/s]

# %%
df = dataset.to_pandas()

# %%
df
# Out:
#                                                   Audio  \
# 0                                   350617_clip_635.wav
# 1     Plogastel_Saint_Germain_NALBB_point_118_a_clip...
# 2                                   350615_clip_265.wav
# 3                             CRBC_BWD_048_clip_234.wav
# 4     Plogastel_Saint_Germain_NALBB_point_118_a_clip...
# ...                                                 ...
# 1561                          CRBC_BWD_035_clip_371.wav
# 1562          Treguennec_NALBB_point_120_a_clip_634.wav
# 1563                           CRBC_BWD_085_clip_91.wav
# 1564                           CRBC_BWD_043_clip_11.wav
# 1565                                350603_clip_731.wav
#
#                                           Transcription  \
# 0                                         diwall deñved
# 1                                     d'an abardaez koa
# 2       penndoulliked x teu d'ober raniked diwezhatoc'h
# 3                       xx d'ar eu ya bah d'ar skolaj !
# 4                                                leueoù
# ...                                                 ...
# 1561  ha goude-se, tud hag a devoa dija bañsionoù x ...
# 1562                                           laboused
# 1563                 sed an dra-se zo kaoz eñ n'eus ket
# 1564                                     gour deuzouten
# 1565                              eu boñ, penaos 'lârit
#
#                                               file_path
# 0     {'bytes': b'RIFF\xec\xc6\x01\x00WAVEfmt \x10\x...
# 1     {'bytes': b'RIFF$\xa1\x04\x00WAVEfmt \x10\x00\...
# 2     {'bytes': b'RIFF\xf0\x95\x05\x00WAVEfmt \x10\x...
# 3     {'bytes': b'RIFF\xb8\x00\x08\x00WAVEfmt \x10\x...
# 4     {'bytes': b'RIFF$\xfe\x01\x00WAVEfmt \x10\x00\...
# ...                                                 ...
# 1561  {'bytes': b'RIFF\xf4&\t\x00WAVEfmt \x10\x00\x0...
# 1562  {'bytes': b'RIFF$&\x04\x00WAVEfmt \x10\x00\x00...
# 1563  {'bytes': b'RIFF\x04\xf4\x04\x00WAVEfmt \x10\x...
# 1564  {'bytes': b'RIFF\x9c\xd2\x03\x00WAVEfmt \x10\x...
# 1565  {'bytes': b'RIFF\xcc\x01\x05\x00WAVEfmt \x10\x...
#
# [1566 rows x 3 columns]

# %%
dataset_path = "/kaggle/input/dastum-test-data/test"

# %%
from transformers import pipeline
# Out:
# 2025-09-16 09:12:10.276612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758013930.617992      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758013930.678711      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model="ArzhurKoadek/whisper-small-br",  # or "OuassimZm/Dastum-yar-stt-breton-data"
    device=0  # use -1 if you want CPU
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def generate_transcription(row):
    audio_filename = row['Audio']  # get the audio file name
    full_path = os.path.join(dataset_path, audio_filename)  # full path to the audio
    return transcribe_audio(full_path, model)

# %%
# !pip install whisper
# Out:
# Collecting whisper
#   Downloading whisper-1.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from whisper) (1.17.0)
# Building wheels for collected packages: whisper
#   Building wheel for whisper (setup.py) ... done
#   Created wheel for whisper: filename=whisper-1.1.10-py3-none-any.whl size=41120 sha256=efa4683974ac297765ea3733e1fe8ea27eee0ceffb27db8e18fe5b33de137faf
#   Stored in directory: /root/.cache/pip/wheels/21/65/ee/4e6672aabfa486d3341a39a04f8f87c77e5156149299b5a7d0
# Successfully built whisper
# Installing collected packages: whisper
# Successfully installed whisper-1.1.10

# %%
import sys

sys.path.append('/kaggle/input/scripts-codes/text')

from transcriber_whisper_old_model import transcribe_audio
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
# Apply transcription
df['transcription'] = df.apply(lambda row: transcribe_audio(
    os.path.join(dataset_path, row['Audio']),
    pipe
), axis=1)

# Optional: reset index if needed
df = df.reset_index(drop=True)
# Out:
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_635.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# You have passed task=transcribe, but also have set `forced_decoder_ids` to [[1, 50259], [2, 50359], [3, 50363]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of task=transcribe.
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_163.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_265.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_234.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_326.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_875.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_561.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_334.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_501.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_572.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_13.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_393.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_422.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_764.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_648.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_144.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_638.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_444.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_60.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_347.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_140.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_3.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_1217.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_171.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_9.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_574.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_648.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_29.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_884.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_755.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_86.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_747.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_239.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_322.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_822.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_35.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_580.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_271.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_836.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_154.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_335.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_331.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_803.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_714.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_320.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_266.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_233.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_813.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_739.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_188.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_543.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_198.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_409.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_357.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_512.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_687.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_667.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_368.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_842.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_126.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_663.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_835.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_799.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_171.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_373.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_89.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_601.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_124.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_385.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_372.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_28.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_406.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_552.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_800.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_486.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_103.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_106.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_329.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_225.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_352.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_296.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_94.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_120.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_308.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_42.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_65.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_370.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_583.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_88.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_177.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_191.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_58.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_6.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_85.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_666.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_622.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_308.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_161.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_1009.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_195.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_12.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_59.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_516.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_124.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_542.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_29.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_141.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_571.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_510.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_144.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_206.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_619.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_31.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_217.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_363.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_163.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_69.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_1.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_644.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_621.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_185.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_245.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_113.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_736.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_531.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_332.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_295.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_653.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_387.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_1039.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_447.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_147.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_903.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_421.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_49.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_526.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_176.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_714.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_106.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_684.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_910.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_418.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_188.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_318.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_314.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_175.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_274.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_162.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_554.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_485.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_878.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_35.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_668.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_175.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_453.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_367.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_25.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_108.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_500.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_118.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_417.wav...
# ...
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_337.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_75.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_298.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_872.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_21.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_554.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_207.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_369.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_46.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_323.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_1071.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_138.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_384.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_159.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_374.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_266.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_1000.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_201.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_754.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_177.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_710.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_1.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_61.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_927.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_606.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_879.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_19.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_539.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_547.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_523.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_163.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_794.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_365.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_194.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_148.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_376.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_38.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_400.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_153.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_515.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_290.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_468.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_528.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_703.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_239.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_83.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_658.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_67.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_883.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_371.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_634.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_91.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_11.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_731.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
fine_tuned_model = "OuassimZm/Whisper-small-fine-tuned"

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained(fine_tuned_model, load_in_8bit=False, device_map="auto")

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model="OuassimZm/Whisper-small-fine-tuned",  # or "OuassimZm/Dastum-yar-stt-breton-data"
    device=0  # use -1 if you want CPU
)
# Out:
# Device set to use cuda:0

# %%
sys.path.append('/kaggle/input/transcriber-whisper')

from transcriber_whisper_fine_tuned import transcribe_audio_new_model

# %%
# Apply tdef generate_transcription(row):
    audio_filename = row['Audio']  # get the audio file name
    full_path = os.path.join(dataset_path, audio_filename)  # full path to the audio
    return transcribe_audio(full_path, model)ranscription
df['transcription_new_model'] = df.apply(lambda row: transcribe_audio_new_model(
    os.path.join(dataset_path, row['Audio']),
    pipe
), axis=1)

# Optional: reset index if needed
df = df.reset_index(drop=True)
# Out:
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_635.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_163.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_265.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_234.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_326.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_875.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_561.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_334.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_501.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_572.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_13.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_393.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_422.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_764.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_648.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_144.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_638.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_444.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_60.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_347.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_140.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_3.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_1217.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_171.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_9.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_574.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_648.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_29.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_884.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_755.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_86.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_747.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_239.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_322.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_822.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_35.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_580.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_271.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_836.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_154.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_335.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_331.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_803.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_714.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_320.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_266.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_233.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_813.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_739.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_188.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_543.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_198.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_409.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_357.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_512.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_687.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_667.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_368.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_842.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_126.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_663.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_835.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_799.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_171.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_373.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_89.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_601.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_124.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_385.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_372.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_28.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_406.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_552.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_800.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_486.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_103.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_106.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_329.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_225.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_352.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_296.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_94.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_120.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_308.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_42.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_65.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_370.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_583.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_88.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_053_clip_177.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_191.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_58.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_6.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_85.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_666.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_622.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_308.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_161.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_1009.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_195.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_12.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_59.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_516.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_124.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_542.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_29.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_141.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_571.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_510.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_144.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_206.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_619.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_31.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_217.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_363.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_163.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_69.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_1.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_644.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_621.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_185.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_245.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_113.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_736.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_531.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_332.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_295.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_653.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_387.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_1039.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_447.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_147.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_903.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_421.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_49.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_526.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_176.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_714.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_106.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_684.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_910.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_418.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_188.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_318.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_314.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_175.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_274.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_162.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_554.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_485.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_878.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_35.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_668.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_175.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_453.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_367.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_25.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_108.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_500.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Loctudy_NALBB_point_122_clip_118.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_417.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_258.wav...
# ...
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_337.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_75.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_298.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_872.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_21.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_554.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_207.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_369.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_46.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_323.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_1071.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_138.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_384.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_159.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_374.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_266.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_1000.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_048_clip_201.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_754.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_177.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_710.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_1.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_61.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_927.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_606.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_879.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_b_clip_19.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_539.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_547.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_523.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_163.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_794.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_365.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_194.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_148.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_376.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_38.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_400.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Plogastel_Saint_Germain_NALBB_point_118_a_clip_153.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_515.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_290.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_468.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_528.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350627_clip_703.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_239.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_83.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350617_clip_658.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_67.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350615_clip_883.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_035_clip_371.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/Treguennec_NALBB_point_120_a_clip_634.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_085_clip_91.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/CRBC_BWD_043_clip_11.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Transcribing /kaggle/input/dastum-test-data/test/350603_clip_731.wav...
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
df
# Out:
#                                                   Audio  \
# 0                                   350617_clip_635.wav
# 1     Plogastel_Saint_Germain_NALBB_point_118_a_clip...
# 2                                   350615_clip_265.wav
# 3                             CRBC_BWD_048_clip_234.wav
# 4     Plogastel_Saint_Germain_NALBB_point_118_a_clip...
# ...                                                 ...
# 1561                          CRBC_BWD_035_clip_371.wav
# 1562          Treguennec_NALBB_point_120_a_clip_634.wav
# 1563                           CRBC_BWD_085_clip_91.wav
# 1564                           CRBC_BWD_043_clip_11.wav
# 1565                                350603_clip_731.wav
#
#                                           Transcription  \
# 0                                         diwall deñved
# 1                                     d'an abardaez koa
# 2       penndoulliked x teu d'ober raniked diwezhatoc'h
# 3                       xx d'ar eu ya bah d'ar skolaj !
# 4                                                leueoù
# ...                                                 ...
# 1561  ha goude-se, tud hag a devoa dija bañsionoù x ...
# 1562                                           laboused
# 1563                 sed an dra-se zo kaoz eñ n'eus ket
# 1564                                     gour deuzouten
# 1565                              eu boñ, penaos 'lârit
#
#                                               file_path  \
# 0     {'bytes': b'RIFF\xec\xc6\x01\x00WAVEfmt \x10\x...
# 1     {'bytes': b'RIFF$\xa1\x04\x00WAVEfmt \x10\x00\...
# 2     {'bytes': b'RIFF\xf0\x95\x05\x00WAVEfmt \x10\x...
# 3     {'bytes': b'RIFF\xb8\x00\x08\x00WAVEfmt \x10\x...
# 4     {'bytes': b'RIFF$\xfe\x01\x00WAVEfmt \x10\x00\...
# ...                                                 ...
# 1561  {'bytes': b'RIFF\xf4&\t\x00WAVEfmt \x10\x00\x0...
# 1562  {'bytes': b'RIFF$&\x04\x00WAVEfmt \x10\x00\x00...
# 1563  {'bytes': b'RIFF\x04\xf4\x04\x00WAVEfmt \x10\x...
# 1564  {'bytes': b'RIFF\x9c\xd2\x03\x00WAVEfmt \x10\x...
# 1565  {'bytes': b'RIFF\xcc\x01\x05\x00WAVEfmt \x10\x...
#
#                                           transcription  \
# 0                                          Deval-devez?
# 1                                   den ar vazhae koad.
# 2        Ben doulik eo se teut e oa re neket livet aze.
# 3                                  Prenion d'ar skolaj?
# 4                                                  div.
# ...                                                 ...
# 1561  Agoutiñ-se, tud hagut a voa dejao, pasioù d’où...
# 1562                                   Peseurt levr-se?
# 1563               S'eo n'eus a-gouz er n'eus ket deus.
# 1564                                   Gor diouzhotenn.
# 1565                                   C'hozh a ra eus?
#
#                                 transcription_new_model
# 0                                         diwall devezh
# 1                                  dind' la vardaez koa
# 2              'benn douligez atav doa raniked diwezhañ
# 3                       en unan, d'ar eu ya d'ar skolaj
# 4                                                  vioù
# ...                                                 ...
# 1561  ha goude-se eu tud hag oad aja o ba'n siou, do...
# 1562                                             sûl-se
# 1563                    set an aze zo kouzhet n'eus ket
# 1564                                  gwoc'h da soutenn
# 1565                           eu bon, penaos eo lâret?
#
# [1566 rows x 5 columns]

# %%
from filter_char import filter_out_chars
from normalizer import normalize_sentence
from utils import pre_process


def process_br_text(br):
    PUNCTUATION = '<>.?!,;:«»“”"()[]/…–—•'
    br = filter_out_chars(br, PUNCTUATION + '*')
    br = normalize_sentence(br, autocorrect=True)
    br = pre_process(br).replace('-', ' ').lower()
    return br

# %%
df['sentence_processed'] = df['Transcription'].apply(process_br_text)
df['transcription_processed'] = df['transcription'].apply(process_br_text)
df['transcription_new_model_processed'] = df['transcription_new_model'].apply(process_br_text)

# %%
from jiwer import wer, cer

# Compute WER and CER for each row
df['wer_old_model'] = df.apply(lambda row: wer(row['sentence_processed'], row['transcription_processed']), axis=1)
df['cer_old_model'] = df.apply(lambda row: cer(row['sentence_processed'], row['transcription_processed']), axis=1)

# %%
from jiwer import wer, cer

# Compute WER and CER for each row
df['wer_new_model'] = df.apply(lambda row: wer(row['sentence_processed'], row['transcription_new_model_processed']), axis=1)
df['cer_new_model'] = df.apply(lambda row: cer(row['sentence_processed'], row['transcription_new_model_processed']), axis=1)

# %%
df = df[['sentence_processed', 'transcription_processed','transcription_new_model_processed', 'wer_new_model', 'wer_old_model', 'cer_new_model', 'cer_old_model']]
df
# Out:
#                                      sentence_processed  \
# 0                                         diwall deñved
# 1                                     d'an abardaez kwa
# 2       penndoulliked x teu d'ober raniked diwezhatoc'h
# 3                         xx d'ar eu ya bah d'ar skolaj
# 4                                                leueoù
# ...                                                 ...
# 1561  ha goude se tud hag a devoa dija bañsionoù x a...
# 1562                                           laboused
# 1563                 sed an dra se zo kaoz eñ n'eus ket
# 1564                                     gour deuzouten
# 1565                                eu boñ penaos lârit
#
#                                 transcription_processed  \
# 0                                           deval devez
# 1                                    den ar vazhae koad
# 2      ben doulik eo se teut e oa re n'eo ket livet aze
# 3                                   prenion d'ar skolaj
# 4                                                   div
# ...                                                 ...
# 1561  agoutiñ se tud hagut a voa dejao pasioù d'où d...
# 1562                                    peseurt levr se
# 1563                s'eo n'eus a gouz er n'eus ket deus
# 1564                                    gor diouzhotenn
# 1565                                    c'hozh a ra eus
#
#                       transcription_new_model_processed  wer_new_model  \
# 0                                         diwall devezh       0.500000
# 1                                  dind' la vardaez kwa       1.000000
# 2               benn douligez atav doa raniked diwezhañ       0.833333
# 3                        en unan d'ar eu ya d'ar skolaj       0.428571
# 4                                                  vioù       1.000000
# ...                                                 ...            ...
# 1561  ha goude se eu tud hag oad aja o ba'n siou don...       0.615385
# 1562                                             sûl se       2.000000
# 1563                    set an aze zo kouzhet n'eus ket       0.555556
# 1564                                  gwoc'h da soutenn       1.500000
# 1565                             eu bon penaos eo lâret       0.750000
#
#       wer_old_model  cer_new_model  cer_old_model
# 0          1.000000       0.230769       0.384615
# 1          1.333333       0.411765       0.588235
# 2          2.000000       0.382979       0.595745
# 3          0.714286       0.379310       0.517241
# 4          1.000000       0.666667       1.000000
# ...             ...            ...            ...
# 1561       0.769231       0.415094       0.509434
# 1562       3.000000       0.750000       1.625000
# 1563       0.888889       0.264706       0.588235
# 1564       1.000000       0.571429       0.428571
# 1565       1.000000       0.263158       0.842105
#
# [1566 rows x 7 columns]

# %%
average_wer_old = df['wer_old_model'].mean()
average_cer_old = df['cer_old_model'].mean()

# Optional: round them
average_wer_old = round(average_wer_old, 2)
average_cer_old = round(average_cer_old, 2)

print(f"Average old model WER: {average_wer_old}")
print(f"Average old model CER: {average_cer_old}")
# Out:
# Average old model WER: 1.87
# Average old model CER: 1.73

# %%
average_wer_new = df['wer_new_model'].mean()
average_cer_new = df['cer_new_model'].mean()

# Optional: round them
average_wer_new = round(average_wer_new, 2)
average_cer_new = round(average_cer_new, 2)

print(f"Average new model WER: {average_wer_new}")
print(f"Average new model CER: {average_cer_new}")
# Out:
# Average new model WER: 0.6
# Average new model CER: 0.38
