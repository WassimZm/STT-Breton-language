# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/scripts-code/text/Whisper_Evaluation_small.ipynb
# /kaggle/input/scripts-code/text/load_ground_truth_common_voice.py
# /kaggle/input/scripts-code/text/definitions.py
# /kaggle/input/scripts-code/text/wazemour@bocal.cs.univ-paris8.fr
# /kaggle/input/scripts-code/text/Evaluation_Departement_Banque.ipynb
# /kaggle/input/scripts-code/text/transcriber_whisper.py
# /kaggle/input/scripts-code/text/Whisper_Evaluation_tiny_2000.ipynb
# /kaggle/input/scripts-code/text/normalizer.py
# /kaggle/input/scripts-code/text/Whisper_Evaluation_base_2000.ipynb
# /kaggle/input/scripts-code/text/filter_char.py
# /kaggle/input/scripts-code/text/transcriber.py
# /kaggle/input/scripts-code/text/gateway-bocal
# /kaggle/input/scripts-code/text/utils.py
# /kaggle/input/scripts-code/text/MP3toWAV.py
# /kaggle/input/scripts-code/text/tokenizer.py
# /kaggle/input/scripts-code/text/load_ground_truth.py
# /kaggle/input/scripts-code/text/Whisper_Evaluation_tiny.ipynb
# /kaggle/input/scripts-code/text/evaluate_wer_cer.py
# /kaggle/input/scripts-code/text/Replace_mp3_wav_in_file.py
# /kaggle/input/scripts-code/text/audio.py
# /kaggle/input/scripts-code/text/Whisper_Evaluation_base.ipynb
# /kaggle/input/scripts-code/text/dicts/corrected_tokens.tsv
# /kaggle/input/scripts-code/text/dicts/first_names.tsv
# /kaggle/input/scripts-code/text/dicts/proper_nouns_phon.tsv
# /kaggle/input/scripts-code/text/dicts/named_entities.tsv
# /kaggle/input/scripts-code/text/dicts/ipa.txt
# /kaggle/input/scripts-code/text/dicts/places.tsv
# /kaggle/input/scripts-code/text/dicts/gwenedeg_trad.tsv
# /kaggle/input/scripts-code/text/dicts/abbreviations.tsv
# /kaggle/input/scripts-code/text/dicts/last_names.tsv
# /kaggle/input/scripts-code/text/dicts/acronyms.tsv
# /kaggle/input/scripts-code/text/dicts/noun_f.tsv
# /kaggle/input/scripts-code/text/dicts/adjectives.tsv
# /kaggle/input/scripts-code/text/dicts/standard_tokens.tsv
# /kaggle/input/scripts-code/text/dicts/stopwords.tsv
# /kaggle/input/scripts-code/text/dicts/gwenedeg_peurunvan.tsv
# /kaggle/input/scripts-code/text/dicts/interjections.tsv
# /kaggle/input/scripts-code/text/dicts/sarmonioù_peurunvan.tsv
# /kaggle/input/scripts-code/text/dicts/countries.tsv
# /kaggle/input/scripts-code/text/dicts/__init__.py
# /kaggle/input/scripts-code/text/dicts/noun_m.tsv
# /kaggle/input/test-tsv/test.tsv
# /kaggle/input/common-voice-data/Test/common_voice_br_17335043.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169427.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40301820.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762704.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738561.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970193.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38903438.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965544.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042373.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327408.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147056.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742626.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27138605.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17334991.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18010008.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18981755.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504341.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17987917.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737909.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737913.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020146.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762695.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43421176.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146837.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737912.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042397.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962302.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19254119.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968504.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41901435.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17963237.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015221.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_39765234.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147017.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832795.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25558023.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150389.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015209.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727933.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25557841.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976675.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25557785.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747266.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351027.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015345.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351060.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129009.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965531.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058449.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962491.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40232338.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142122.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962492.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19352122.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17801014.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18009989.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21637082.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41828053.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17332429.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966907.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142125.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015331.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18378047.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17801011.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015338.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970167.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_22694671.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951505.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976657.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40301333.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727943.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18378023.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737924.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18019952.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18143093.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013184.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141800.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962472.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17972576.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40055077.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150360.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19254019.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742622.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129008.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351035.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966867.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738593.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848300.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849380.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169601.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18900837.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18128986.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832875.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37416702.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762594.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965068.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737982.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146870.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738554.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335008.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18187629.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146798.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965836.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028254.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976303.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18981725.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970169.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141899.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_30727990.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142137.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42739810.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738545.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40343743.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968482.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962098.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18009965.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21637265.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848177.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738570.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150395.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42807655.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142139.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142294.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142211.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17801012.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19542675.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965523.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41828180.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38884587.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17766807.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40343741.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849392.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37307632.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17980480.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17969320.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376556.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976721.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40327688.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18081144.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335046.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970237.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747234.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17974791.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17332430.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147041.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141900.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17805591.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970495.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848319.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848316.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351003.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762592.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951489.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015136.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_20323755.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18762497.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042418.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17980461.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_32821471.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18079813.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40055078.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19446751.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327427.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762746.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_32956492.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327722.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965458.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17967351.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966786.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41828260.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951527.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738587.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25557782.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19253867.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18762510.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17334993.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18006496.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43427348.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762748.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964856.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18035108.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_30728033.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40327686.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37416687.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015212.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747236.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43421169.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849599.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19446755.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17998028.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968468.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376532.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738540.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020100.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42933776.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40054939.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18378036.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38711540.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015220.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43421174.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17967998.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020102.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40273468.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504814.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832798.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23949800.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40327707.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169604.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504828.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17805589.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020169.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40262439.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18229284.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832796.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968505.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964721.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020227.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020059.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37906335.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_20323743.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40273466.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40251332.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738597.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146834.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848379.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742732.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970114.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18900756.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17402842.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18143094.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147034.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504794.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970496.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129036.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142107.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43421405.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013163.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21480351.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18019990.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849322.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970155.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17980457.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848186.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27160027.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376555.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18229283.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327407.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327409.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147051.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964977.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951495.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742653.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727950.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18762780.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40232011.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727941.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965439.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335032.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976707.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962679.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147030.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727901.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976679.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19253922.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504824.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727942.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38373327.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951521.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141751.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27160040.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376517.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23892773.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18036191.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976667.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015323.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23697533.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27123691.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18009976.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968371.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727896.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18079816.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17982375.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42807658.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25557842.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_30728034.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966952.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848368.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738592.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25558056.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966866.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747267.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37906284.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964998.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18081134.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141880.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146824.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020224.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146838.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17862514.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169426.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146788.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19253950.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18151126.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17334210.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19308099.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17345768.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42807662.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848185.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18770232.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351059.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966951.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020061.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21238237.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327440.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738577.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17973152.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18008573.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742652.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504752.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150369.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41901436.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966485.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21637048.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18081147.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742750.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504753.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18036177.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965070.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962676.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18728547.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848172.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504783.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40232012.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976719.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169421.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17961891.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19253949.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40054940.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18762498.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19253868.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23862118.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504768.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150374.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042396.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966015.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37416701.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25558121.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747224.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058494.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335002.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169422.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742650.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738600.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727949.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964986.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21637079.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968373.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17973156.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18036166.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951488.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150411.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966019.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848322.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147022.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849596.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013181.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38903434.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762500.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028251.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17332438.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028182.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727913.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147039.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38373326.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727940.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058468.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141748.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504344.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40054936.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020025.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976651.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18981784.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849543.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150393.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013201.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17967353.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17402832.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013188.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504784.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_22472045.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738547.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970133.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327443.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970166.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147052.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042404.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327383.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058498.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169424.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504780.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848347.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17978495.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727945.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17978497.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737975.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832840.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18005713.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19893878.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376558.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968705.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335020.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17973151.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327464.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17980452.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015351.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962099.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142092.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832828.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058450.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058457.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18010018.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38711555.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18882746.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18482779.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504817.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37906343.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18378037.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968011.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_32330635.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_20463820.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762656.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18005706.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951532.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951544.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042364.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968002.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964989.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_39321751.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18762783.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40262440.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19893880.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142412.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42933778.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17766847.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27138153.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37416723.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147027.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015350.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_30728030.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951549.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376537.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142121.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23949852.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17363453.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18981733.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028253.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964993.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_32236537.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376533.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17345776.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18027745.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_39321720.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17862513.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25558047.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17862516.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015153.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18504816.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169446.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742689.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849810.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762502.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17334992.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058456.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19308103.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964968.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141855.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848378.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970116.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335045.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17805543.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015326.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17967982.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_39765235.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17967985.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19254237.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_30728043.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17980478.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25558118.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43353800.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028207.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42807659.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129002.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42343906.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762543.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742740.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951542.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150340.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40301472.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327466.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40251257.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742690.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848346.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23949801.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832833.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727946.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18981732.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848169.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19893879.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058485.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727934.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335006.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17332406.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42343907.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737927.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020044.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335042.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129019.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18079812.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37307629.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18058491.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848314.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965546.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41832855.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327429.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17402831.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335004.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042401.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504891.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40301335.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738539.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169602.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962677.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141856.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015299.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762734.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742623.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_39984546.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40232228.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737955.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19254240.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18005715.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742707.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970106.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848349.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21385138.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015190.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146802.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147021.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762611.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727892.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015218.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17766805.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962322.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966489.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_22694682.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968537.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335013.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965573.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129035.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142160.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43376530.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_34504901.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_25558122.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17349070.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335027.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762731.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18181244.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762672.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169444.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747253.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17970109.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727911.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965000.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_40055081.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742749.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964767.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849700.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17799556.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013121.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37924605.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742674.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142074.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742678.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142413.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738590.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141780.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_32821449.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21385141.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37307633.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737970.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23949839.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18951492.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968384.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17862522.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738552.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141812.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17962476.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747223.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142444.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146853.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23892739.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150373.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327468.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141835.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17848380.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351049.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015160.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976650.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42742628.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_22694693.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43421168.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18042387.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_36762694.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17980458.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015216.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737978.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_39321754.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028288.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_22694536.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727928.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147026.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42737933.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17982376.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968703.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17351001.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18079726.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17974789.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_29621045.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17978508.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849703.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19308076.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013172.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968431.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37906357.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17964864.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18378035.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41849759.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_32330618.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_42738556.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17967988.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17976722.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18013186.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_22696936.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38157069.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966481.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18128981.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849349.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17974792.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18327406.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21388910.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849540.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18900758.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27138606.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17335007.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17337747.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21445933.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_43219672.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17965462.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18028290.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141842.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18129028.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23949836.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015214.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968470.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18169431.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17966042.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747259.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27124388.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015192.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17747260.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37416683.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18128977.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_27160042.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18150361.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_19737696.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17862532.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18141804.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_37623733.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18981762.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17968334.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_41828261.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17331788.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23727904.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18020026.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_17766803.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_21385093.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18015347.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_23949818.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_26849353.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18142411.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_18146854.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38147049.mp3
# /kaggle/input/common-voice-data/Test/common_voice_br_38711535.mp3
# ...
# /kaggle/input/banque-sonore-data/Audio/utt_00857.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00690.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01840.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04326.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00706.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02757.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06932.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03079.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03666.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05523.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00681.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03261.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03698.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05468.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03961.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05351.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03991.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01137.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06242.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00219.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02240.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06636.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01867.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03661.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02423.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02832.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02367.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01107.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02590.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03569.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00814.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05397.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04168.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05251.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03792.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05817.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04802.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05832.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00699.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02108.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00512.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03215.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05651.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04817.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04484.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06176.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03509.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06895.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06226.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01285.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06159.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06974.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00110.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02157.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03068.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01008.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05097.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02899.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03322.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06109.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00844.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03767.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01094.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06730.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04420.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05865.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00880.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04441.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02728.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01523.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00352.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04862.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05747.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05187.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04787.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04291.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01526.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04124.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03392.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04244.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07282.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02117.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00702.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01053.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00761.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06690.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00594.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07240.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03520.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02817.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00676.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01726.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05057.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03836.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02530.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06430.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06251.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03300.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02296.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03907.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03589.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01306.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05772.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07100.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05137.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04135.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02968.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02878.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00599.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05245.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01181.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01653.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00750.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02990.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05486.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05339.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04801.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02245.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05014.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00024.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01395.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02725.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02439.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05026.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00960.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03931.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01060.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06709.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02891.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04620.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06104.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05284.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02888.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05939.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03036.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04688.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01746.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05144.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03641.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06006.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07053.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00112.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02484.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03358.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01088.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02908.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04043.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04346.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00231.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05837.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03371.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00185.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00277.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03857.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02302.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05009.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03718.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01147.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06492.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01957.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03448.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01432.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03996.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04150.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04660.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02392.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01685.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06661.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05381.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02557.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01159.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05992.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05994.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04989.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05186.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03024.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01868.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02843.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01026.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05787.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01971.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03936.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00826.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03226.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07127.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03355.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04010.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03714.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04487.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02709.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00970.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06123.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01861.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04543.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03132.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02844.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04656.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02546.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01673.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03521.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06668.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06864.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06477.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04698.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04186.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04530.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05151.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05745.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05810.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05793.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04892.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04236.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07289.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07144.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03059.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02119.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05909.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00614.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02916.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06440.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02434.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05274.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05977.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05348.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00392.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05475.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00808.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00872.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00579.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01149.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03841.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03596.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05048.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01210.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05143.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05614.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06646.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04712.wav
# /kaggle/input/banque-sonore-data/Audio/spk2utt
# /kaggle/input/banque-sonore-data/Audio/utt_05280.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03737.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06211.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04945.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02182.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03108.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02231.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00444.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05853.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05101.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02234.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00250.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00551.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06708.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05285.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03529.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06038.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07045.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03816.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04827.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06866.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03866.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00127.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00850.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05377.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05494.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04702.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05326.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06462.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02290.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01412.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06069.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07002.wav
# /kaggle/input/banque-sonore-data/Audio/utt_05875.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03321.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02260.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02430.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04575.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03026.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00744.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01340.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03086.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03565.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01753.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00106.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01250.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03985.wav
# /kaggle/input/banque-sonore-data/Audio/utt2dur
# /kaggle/input/banque-sonore-data/Audio/utt_04673.wav
# /kaggle/input/banque-sonore-data/Audio/utt_01819.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06397.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03220.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00221.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00563.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06569.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03402.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03528.wav
# /kaggle/input/banque-sonore-data/Audio/utt_06271.wav
# /kaggle/input/banque-sonore-data/Audio/utt_04298.wav
# /kaggle/input/banque-sonore-data/Audio/utt_00620.wav
# /kaggle/input/banque-sonore-data/Audio/utt_02687.wav
# /kaggle/input/banque-sonore-data/Audio/utt_03474.wav
# /kaggle/input/banque-sonore-data/Audio/utt_07133.wav

# %%
# !pip install -q transformers datasets torchaudio

# %%
# !pip install -q librosa soundfile

# %%
from transformers import pipeline

# %%
asr = pipeline("automatic-speech-recognition", model="gweltou/wav2vec2-xls-r-300m-br")
# Out:
# Device set to use cuda:0

# %%
result = asr("/kaggle/input/banque-sonore-data/Audio/utt_00000.wav")
print(result["text"])
# Out:
# pell zo n'eo ket bet  e c'hwel'h anañ

# %%
import sys

sys.path.append('/kaggle/input/scripts-code/text')


from load_ground_truth_common_voice import load_ground_truth_dict_commonvoice

# %%
# !pip install jiwer
# Out:
# Requirement already satisfied: jiwer in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.2.1)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /usr/local/lib/python3.11/dist-packages (from jiwer) (3.13.0)

# %%
import os
import json
import jiwer

import sys

# %%
import pandas as pd

tsv_file="/kaggle/input/test-tsv/test.tsv"
# Read the TSV file into a DataFrame
df = pd.read_csv(tsv_file, sep='\t')

df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                               client_id  \
# 0     20c2ec32d71eb83bd7878d32354cf7ed1387b0cf8c0244...
# 1     28549a5a700d20b91b7c5729ab381b3de5f3ef7b39896d...
# 2     601b90c17534eafa23b4c3d9056562d5ae7f3a4e09ba66...
# 3     644a43f222bf6121fccc51e3995fad29c937d0c67e2652...
# 4     6f9932e48b262881952f248473d5e56e25fbf4608d79c7...
# ...                                                 ...
# 2860  37350e73c62e7ba51aca62e2e850852e5fc0529881992a...
# 2861  37350e73c62e7ba51aca62e2e850852e5fc0529881992a...
# 2862  37350e73c62e7ba51aca62e2e850852e5fc0529881992a...
# 2863  37350e73c62e7ba51aca62e2e850852e5fc0529881992a...
# 2864  37350e73c62e7ba51aca62e2e850852e5fc0529881992a...
#
#                               path  \
# 0     common_voice_br_43418986.mp3
# 1     common_voice_br_18382821.mp3
# 2     common_voice_br_17977507.mp3
# 3     common_voice_br_41622444.mp3
# 4     common_voice_br_19737696.mp3
# ...                            ...
# 2860  common_voice_br_17994057.mp3
# 2861  common_voice_br_17995860.mp3
# 2862  common_voice_br_17996179.mp3
# 2863  common_voice_br_17998028.mp3
# 2864  common_voice_br_17999626.mp3
#
#                                             sentence_id  \
# 0     1f2c296645f2350caab2a1b020bdca95b9c5997f49a857...
# 1     1956f9fa11493b990b8e4d902dd02c9cd5b744ba539367...
# 2     88a54965ce62fa884bb2156ed7ab051410e40161481e64...
# 3     83dabe599e2706e4fcbb78c6084b364c0e268c0d541fe2...
# 4     c2b949dd328e1ca91003278af8831a1cfc7f784c225089...
# ...                                                 ...
# 2860  746b3e1ba4b1e90fd730feef0ee74421edcc90e220479c...
# 2861  be0d10e614a2afd816043b51fbaa674dda05334c7f8bb4...
# 2862  c365c47e239116c4493b9e8eb5f0eaf365da027d707e34...
# 2863  d81e755e5f77c0cf0483082e015ec2e8cdbb5a686ffc1d...
# 2864  c431166017ee66a4dd1a07ecf5371f1038840468060c8a...
#
#                                         sentence sentence_domain  up_votes  \
# 0                     Kanañ a raent en hent don.         general         2
# 1                       digor e vez da Verc'her.             NaN         2
# 2        Re nebeut a zo deuet da reiñ dorn dimp.             NaN         2
# 3                  Kemerit ho tafar hag azezit !             NaN         2
# 4                                   Be'h dezhi !             NaN         2
# ...                                          ...             ...       ...
# 2860      Ar memes tra a vo gulennet diganeoc'h.             NaN         2
# 2861  Alies em galv da zont da reiñ dorn dezhañ.             NaN         2
# 2862                              Me/ Te. Eñ/Hi.             NaN         2
# 2863         Ar c'harr-tan ruz nevez-flamm-hont.             NaN         2
# 2864     gwelet a rin anezhañ dimerc'her kentañ.             NaN         2
#
#       down_votes  age gender accents  variant locale segment
# 0              0  NaN    NaN     NaN      NaN     br     NaN
# 1              0  NaN    NaN     NaN      NaN     br     NaN
# 2              0  NaN    NaN     NaN      NaN     br     NaN
# 3              0  NaN    NaN     NaN      NaN     br     NaN
# 4              1  NaN    NaN     NaN      NaN     br     NaN
# ...          ...  ...    ...     ...      ...    ...     ...
# 2860           1  NaN    NaN     NaN      NaN     br     NaN
# 2861           0  NaN    NaN     NaN      NaN     br     NaN
# 2862           0  NaN    NaN     NaN      NaN     br     NaN
# 2863           0  NaN    NaN     NaN      NaN     br     NaN
# 2864           0  NaN    NaN     NaN      NaN     br     NaN
#
# [2865 rows x 13 columns]

# %%
df = df[['path','sentence','gender','sentence_domain','age','accents']]

df
# Out:
#                               path  \
# 0     common_voice_br_43418986.mp3
# 1     common_voice_br_18382821.mp3
# 2     common_voice_br_17977507.mp3
# 3     common_voice_br_41622444.mp3
# 4     common_voice_br_19737696.mp3
# ...                            ...
# 2860  common_voice_br_17994057.mp3
# 2861  common_voice_br_17995860.mp3
# 2862  common_voice_br_17996179.mp3
# 2863  common_voice_br_17998028.mp3
# 2864  common_voice_br_17999626.mp3
#
#                                         sentence gender sentence_domain  age  \
# 0                     Kanañ a raent en hent don.    NaN         general  NaN
# 1                       digor e vez da Verc'her.    NaN             NaN  NaN
# 2        Re nebeut a zo deuet da reiñ dorn dimp.    NaN             NaN  NaN
# 3                  Kemerit ho tafar hag azezit !    NaN             NaN  NaN
# 4                                   Be'h dezhi !    NaN             NaN  NaN
# ...                                          ...    ...             ...  ...
# 2860      Ar memes tra a vo gulennet diganeoc'h.    NaN             NaN  NaN
# 2861  Alies em galv da zont da reiñ dorn dezhañ.    NaN             NaN  NaN
# 2862                              Me/ Te. Eñ/Hi.    NaN             NaN  NaN
# 2863         Ar c'harr-tan ruz nevez-flamm-hont.    NaN             NaN  NaN
# 2864     gwelet a rin anezhañ dimerc'her kentañ.    NaN             NaN  NaN
#
#      accents
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 2860     NaN
# 2861     NaN
# 2862     NaN
# 2863     NaN
# 2864     NaN
#
# [2865 rows x 6 columns]

# %%
dataset_path = "/kaggle/input/common-voice-data/Test"

# %%
df
# Out:
#                               path  \
# 0     common_voice_br_43418986.mp3
# 1     common_voice_br_18382821.mp3
# 2     common_voice_br_17977507.mp3
# 3     common_voice_br_41622444.mp3
# 4     common_voice_br_19737696.mp3
# ...                            ...
# 2860  common_voice_br_17994057.mp3
# 2861  common_voice_br_17995860.mp3
# 2862  common_voice_br_17996179.mp3
# 2863  common_voice_br_17998028.mp3
# 2864  common_voice_br_17999626.mp3
#
#                                         sentence gender sentence_domain  age  \
# 0                     Kanañ a raent en hent don.    NaN         general  NaN
# 1                       digor e vez da Verc'her.    NaN             NaN  NaN
# 2        Re nebeut a zo deuet da reiñ dorn dimp.    NaN             NaN  NaN
# 3                  Kemerit ho tafar hag azezit !    NaN             NaN  NaN
# 4                                   Be'h dezhi !    NaN             NaN  NaN
# ...                                          ...    ...             ...  ...
# 2860      Ar memes tra a vo gulennet diganeoc'h.    NaN             NaN  NaN
# 2861  Alies em galv da zont da reiñ dorn dezhañ.    NaN             NaN  NaN
# 2862                              Me/ Te. Eñ/Hi.    NaN             NaN  NaN
# 2863         Ar c'harr-tan ruz nevez-flamm-hont.    NaN             NaN  NaN
# 2864     gwelet a rin anezhañ dimerc'her kentañ.    NaN             NaN  NaN
#
#      accents
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 2860     NaN
# 2861     NaN
# 2862     NaN
# 2863     NaN
# 2864     NaN
#
# [2865 rows x 6 columns]

# %%
result = asr("/kaggle/input/common-voice-data/Test/common_voice_br_17998028.mp3")
print(result["text"])
# Out:
# ar c'hartan ruz nevez flamm maon

# %%
def get_transcription(row):
    audio_path = f"/kaggle/input/common-voice-data/Test/{row['path']}"
    result = asr(audio_path)
    print(f"Processed : {row['path']} => {result}")
    return result

# %%
df["Transcription"] = df.apply(get_transcription, axis=1)

# Optional: reset index if needed
df = df.reset_index(drop=True)
# Out:
# Processed : common_voice_br_43418986.mp3 => {'text': 'kanañ a raint en en don'}
# Processed : common_voice_br_18382821.mp3 => {'text': "digor vez da vec'her"}
# Processed : common_voice_br_17977507.mp3 => {'text': "re nebeut a zo dibet da rein d'an deomper"}
# Processed : common_voice_br_41622444.mp3 => {'text': "kemerit ho tafoc'h hag azezit"}
# Processed : common_voice_br_19737696.mp3 => {'text': "bec'hchwa davoued"}
# Processed : common_voice_br_25993226.mp3 => {'text': 'ur vag dre lien'}
# Processed : common_voice_br_23697533.mp3 => {'text': 'en e bezh e kouezhet er poull'}
# Processed : common_voice_br_32956492.mp3 => {'text': 'braso rik e vo ar bern'}
# Processed : common_voice_br_20463817.mp3 => {'text': 'sot eo wa yan parhataenk kant an avalo doar e vez'}
# Processed : common_voice_br_20463820.mp3 => {'text': 'dre a man eo'}
# Processed : common_voice_br_43419618.mp3 => {'text': "skwelhc'h emaoc' un dealc'h"}
# Processed : common_voice_br_43419621.mp3 => {'text': 'gwir eo'}
# Processed : common_voice_br_42933776.mp3 => {'text': 'maonn en herag'}
# Processed : common_voice_br_42933778.mp3 => {'text': 'hag abek a zo evil just'}
# Processed : common_voice_br_32400446.mp3 => {'text': "har c'hañv bleu breizh izeln"}
# Processed : common_voice_br_32400447.mp3 => {'text': 'ne oa ket aet kuit div vunutenn a oa ma tegouezas egile'}
# Processed : common_voice_br_24011094.mp3 => {'text': 'en alennoù'}
# Processed : common_voice_br_24011095.mp3 => {'text': 'neo ket strikt'}
# Processed : common_voice_br_19325013.mp3 => {'text': "s g e arabat komz ar re gare 'hspe tu dobert kent"}
# Processed : common_voice_br_19325014.mp3 => {'text': 'da vez go o o yaea snañse a ne n doen kos  diouzh ar yez sestu i koi aaos'}
# Processed : common_voice_br_43419624.mp3 => {'text': 'goardiurod'}
# Processed : common_voice_br_43419625.mp3 => {'text': 'ne fellaz dezhañ kemer gwenneg ebet'}
# Processed : common_voice_br_17961853.mp3 => {'text': 'petra eo un tramm tren'}
# Processed : common_voice_br_17961854.mp3 => {'text': "daoust ha kevret hidi alamagn ha chomo e c'hevredidig da viken"}
# Processed : common_voice_br_43353799.mp3 => {'text': 'un tamnig degalone ket hon det neuze'}
# Processed : common_voice_br_43353800.mp3 => {'text': 'tud deuet a ziabell'}
# Processed : common_voice_br_17363451.mp3 => {'text': 'henezh wenn'}
# Processed : common_voice_br_17363452.mp3 => {'text': "n'on ket seur em lazet ar goulou raok mont e maez"}
# Processed : common_voice_br_17363453.mp3 => {'text': "penaos a pelec'h heler mezañ stummet"}
# Processed : common_voice_br_17337747.mp3 => {'text': 'glavu a vo ho hiv es aus gaz'}
# Processed : common_voice_br_17337748.mp3 => {'text': "pha koumz eoa c'hoazh a saviteiñ ar brezhon"}
# Processed : common_voice_br_17337749.mp3 => {'text': 'kupenn karet hon honm eus'}
# Processed : common_voice_br_17332503.mp3 => {'text': 'deus degwener'}
# Processed : common_voice_br_17332504.mp3 => {'text': 'lavarit un dra bennak'}
# Processed : common_voice_br_17332505.mp3 => {'text': 'labourat a ra ho kreg'}
# Processed : common_voice_br_23862117.mp3 => {'text': "sec'het am eus"}
# Processed : common_voice_br_23862118.mp3 => {'text': 'ur gardeu vilon wars all'}
# Processed : common_voice_br_23862119.mp3 => {'text': "bec'h tezhi"}
# Processed : common_voice_br_19126911.mp3 => {'text': 'unan bennak'}
# Processed : common_voice_br_19126912.mp3 => {'text': 'meam eus a gweled'}
# Processed : common_voice_br_19126914.mp3 => {'text': 'ar vrasañ'}
# Processed : common_voice_br_22767275.mp3 => {'text': "deus paz por c'hoant"}
# Processed : common_voice_br_22767278.mp3 => {'text': 'daou vanedour mar plij'}
# Processed : common_voice_br_22767279.mp3 => {'text': 'o vont emañ'}
# Processed : common_voice_br_22696936.mp3 => {'text': "teirc'hies"}
# Processed : common_voice_br_22696938.mp3 => {'text': "ec'h a ra ingal war siberi"}
# Processed : common_voice_br_22696939.mp3 => {'text': "pegourzh c'hoac' ann"}
# Processed : common_voice_br_17983197.mp3 => {'text': 'fall put'}
# Processed : common_voice_br_17983198.mp3 => {'text': "pelec'h emañ ar roadennoù diavez"}
# Processed : common_voice_br_17983200.mp3 => {'text': 'saozneg'}
# Processed : common_voice_br_17349068.mp3 => {'text': 'eus peseurt liv'}
# Processed : common_voice_br_17349069.mp3 => {'text': 'ha bez ez eus nemedennoù'}
# Processed : common_voice_br_17349070.mp3 => {'text': 'eizh ti'}
# Processed : common_voice_br_18035105.mp3 => {'text': 'ur bern traoù zo ganin da zebriñ'}
# Processed : common_voice_br_18035107.mp3 => {'text': 'eviton me ne dint ket'}
# Processed : common_voice_br_18035108.mp3 => {'text': 'det enet dont gant al levr mañ'}
# Processed : common_voice_br_18035109.mp3 => {'text': 'sur out e karin'}
# Processed : common_voice_br_19893876.mp3 => {'text': 'ya'}
# Processed : common_voice_br_19893878.mp3 => {'text': 'alias em beze riou e pad ar goañv'}
# Processed : common_voice_br_19893879.mp3 => {'text': "da c'hoar a garjet"}
# Processed : common_voice_br_19893880.mp3 => {'text': 'mont a reot gant an nijerez pegant han tren'}
# Processed : common_voice_br_18482777.mp3 => {'text': "afer hon eu tu da youlvat preiz zo sikour ac'hanomp pedur reiñ munoioù nevez deomp a ben naovzeiñ arbed enno efeson"}
# Processed : common_voice_br_18482778.mp3 => {'text': 'ur banni digor kalon po'}
# Processed : common_voice_br_18482779.mp3 => {'text': 'ar baotred vihan'}
# Processed : common_voice_br_18482780.mp3 => {'text': 'dre liesell on deuet'}
# Processed : common_voice_br_17969318.mp3 => {'text': "na sec'hed am eus"}
# Processed : common_voice_br_17969319.mp3 => {'text': "da c'hoar a garas"}
# Processed : common_voice_br_17969320.mp3 => {'text': 'biv eur goude anternoz'}
# Processed : common_voice_br_17969321.mp3 => {'text': 'abalemourdezhañ e koez an avaloù war an doar'}
# Processed : common_voice_br_17970235.mp3 => {'text': 'penaos dont da wezañ ezel eus ar bodadoù'}
# Processed : common_voice_br_17970236.mp3 => {'text': 'skuizh on'}
# Processed : common_voice_br_17970237.mp3 => {'text': 'pegoulz eo bet arman'}
# Processed : common_voice_br_17970238.mp3 => {'text': 'dour ha do ugent'}
# Processed : common_voice_br_17962676.mp3 => {'text': 'pvazr olifant ha tregont'}
# Processed : common_voice_br_17962677.mp3 => {'text': "furman ur film a faout deoc'h"}
# Processed : common_voice_br_17962678.mp3 => {'text': 'ha kauet azh peus anezho'}
# Processed : common_voice_br_17962679.mp3 => {'text': "geleuc'ha ouzh skouezh a lein"}
# Processed : common_voice_br_18151125.mp3 => {'text': "yan'eo ket stan ket an hent"}
# Processed : common_voice_br_18151126.mp3 => {'text': 'glav zo gante'}
# Processed : common_voice_br_18151127.mp3 => {'text': 'deuet a oa ar bitros da ganañ'}
# Processed : common_voice_br_18151128.mp3 => {'text': "pitr 'n eus kemeret perzh"}
# Processed : common_voice_br_39765234.mp3 => {'text': "pesk a gecunan d'ar gwinir"}
# Processed : common_voice_br_39765235.mp3 => {'text': 'enem mui rein i ma tommaz'}
# Processed : common_voice_br_39765236.mp3 => {'text': 'kla da arwerieoù ar daol ur saloñs en oi man da tav'}
# Processed : common_voice_br_39765238.mp3 => {'text': "teucho moaiont d'ar gober mui"}
# Processed : common_voice_br_18504339.mp3 => {'text': "hag o vont da skoazellañ anezhed hemaoc'h"}
# Processed : common_voice_br_18504341.mp3 => {'text': 'mat tre eo'}
# Processed : common_voice_br_18504342.mp3 => {'text': 'en eur gêr'}
# Processed : common_voice_br_18504344.mp3 => {'text': "rak oc'h chalet"}
# Processed : common_voice_br_17967351.mp3 => {'text': "ur pelac'h oc'h"}
# Processed : common_voice_br_17967353.mp3 => {'text': "gweil e'm eus peñm a neuze"}
# Processed : common_voice_br_17967354.mp3 => {'text': 'yein e beut e miz jwenver'}
# Processed : common_voice_br_17967355.mp3 => {'text': 'he bennañ'}
# Processed : common_voice_br_17451968.mp3 => {'text': "re vrav eo ar plac'h mañ"}
# Processed : common_voice_br_17451969.mp3 => {'text': 'ar re zu'}
# Processed : common_voice_br_17451970.mp3 => {'text': 'amzer domm zo'}
# Processed : common_voice_br_17451971.mp3 => {'text': 'un tamm diet on'}
# Processed : common_voice_br_18900835.mp3 => {'text': "hor c'he"}
# Processed : common_voice_br_18900836.mp3 => {'text': "c'hwi hoc'h eus bet karet"}
# Processed : common_voice_br_18900837.mp3 => {'text': "enkrez e doa a leizh e c'halomp"}
# Processed : common_voice_br_18900838.mp3 => {'text': 'sur on e karzenn'}
# Processed : common_voice_br_17970495.mp3 => {'text': 'pevar millitrad dour'}
# Processed : common_voice_br_17970496.mp3 => {'text': "peder radoc'h vras"}
# Processed : common_voice_br_17970498.mp3 => {'text': 'war an diwezhad pajenn eo skrivet'}
# Processed : common_voice_br_17970499.mp3 => {'text': "hor'h he loeroù"}
# Processed : common_voice_br_18392653.mp3 => {'text': "da c'hoar a galo"}
# Processed : common_voice_br_18392655.mp3 => {'text': 'bet un e rin amañ'}
# Processed : common_voice_br_18392656.mp3 => {'text': 'poant mañ e dav tumebmañ anezi'}
# Processed : common_voice_br_18392657.mp3 => {'text': 'da ent'}
# Processed : common_voice_br_17961838.mp3 => {'text': 'blea mat ez eo'}
# Processed : common_voice_br_17961839.mp3 => {'text': 'plen och rit vi'}
# Processed : common_voice_br_17961840.mp3 => {'text': 'ker'}
# Processed : common_voice_br_17961841.mp3 => {'text': 'len a ra yñ'}
# Processed : common_voice_br_38373325.mp3 => {'text': "petra a c'hoazh"}
# Processed : common_voice_br_38373326.mp3 => {'text': "un nan e vo e kember e mic'hwer e hag ununan all e bres emaeiz ebreloù"}
# Processed : common_voice_br_38373327.mp3 => {'text': "n'out ket pres eo prest aon"}
# Processed : common_voice_br_38373328.mp3 => {'text': "penaos eo deu a soñj mañ deoc'h"}
# Processed : common_voice_br_18728543.mp3 => {'text': "pegoulz eo bet digoret a nor ganeoc'"}
# Processed : common_voice_br_18728545.mp3 => {'text': 'gallout a reer lezell pezhioù er paod a'}
# Processed : common_voice_br_18728546.mp3 => {'text': 'ur bern arana vo roet'}
# Processed : common_voice_br_18728547.mp3 => {'text': 'petra a ra an dud amañ'}
# Processed : common_voice_br_19542671.mp3 => {'text': 'douet e oa hep bezampedet'}
# Processed : common_voice_br_19542672.mp3 => {'text': "n'ouzon ket pe rae kemeoch"}
# Processed : common_voice_br_19542673.mp3 => {'text': 'petra e voa ar re se'}
# Processed : common_voice_br_19542674.mp3 => {'text': 'goulenn a rama teo'}
# Processed : common_voice_br_19542675.mp3 => {'text': 'na soñj dit te'}
# Processed : common_voice_br_38903433.mp3 => {'text': 'saotret am eus da roched wenn'}
# Processed : common_voice_br_38903434.mp3 => {'text': "ur film o p' eus da erbedit din"}
# Processed : common_voice_br_38903435.mp3 => {'text': 'aozroù patatez na vutun ket mui'}
# Processed : common_voice_br_38903438.mp3 => {'text': "frondek e ta vleudioù na c'homantaer out"}
# Processed : common_voice_br_38903441.mp3 => {'text': "da c'hoar a gar a gar"}
# Processed : common_voice_br_39984542.mp3 => {'text': "piv e c'hallfe lavar d'ar c'hantoll"}
# Processed : common_voice_br_39984543.mp3 => {'text': 'kezek a zebrez pen ne oa kig ebet all'}
# Processed : common_voice_br_39984544.mp3 => {'text': 'bargeriadenn zo glad brav'}
# Processed : common_voice_br_39984545.mp3 => {'text': "gounit darc'hant ruz arc'hant bras"}
# Processed : common_voice_br_39984546.mp3 => {'text': 'an deoù a heaolieg anezhañ'}
# Processed : common_voice_br_17799555.mp3 => {'text': "piv ecs e kouro ac'hanoc'h"}
# Processed : common_voice_br_17799556.mp3 => {'text': 'daou in'}
# Processed : common_voice_br_17799557.mp3 => {'text': "bras a waloc'h"}
# Processed : common_voice_br_17799558.mp3 => {'text': 'gwener un ifern'}
# Processed : common_voice_br_17799559.mp3 => {'text': "an dud se n'euz e bron tamm frouezh ebet"}
# Processed : common_voice_br_17962731.mp3 => {'text': "dior roui da c'hoari"}
# Processed : common_voice_br_17962732.mp3 => {'text': 'daou digwenn ha tregont'}
# Processed : common_voice_br_17962733.mp3 => {'text': "e leizh n'o deus ti ebet zokemp"}
# Processed : common_voice_br_17962734.mp3 => {'text': "dec'hen deoc'h edo o walc'hi gouer ar prenestro"}
# Processed : common_voice_br_17962735.mp3 => {'text': 'sur on e karfent'}
# Processed : common_voice_br_17801010.mp3 => {'text': 'ar bleiz eo gant tri fimor pin'}
# Processed : common_voice_br_17801011.mp3 => {'text': 'fentuz eo'}
# Processed : common_voice_br_17801012.mp3 => {'text': 'eit ma pesketfet'}
# Processed : common_voice_br_17801013.mp3 => {'text': 'karet a raio ma mamm'}
# Processed : common_voice_br_17801014.mp3 => {'text': 'kit war reun goude troiñ da gleiz a zeo'}
# Processed : common_voice_br_17972575.mp3 => {'text': 'ker he koustet deomp'}
# Processed : common_voice_br_17972576.mp3 => {'text': 'alvokad eo ma zad'}
# Processed : common_voice_br_17972577.mp3 => {'text': "teir flac'h"}
# Processed : common_voice_br_17972578.mp3 => {'text': 'gwall vrav eo'}
# Processed : common_voice_br_17961887.mp3 => {'text': 'trugarez evit o skoazenn'}
# Processed : common_voice_br_17961888.mp3 => {'text': 'ouzhpenn div ver e deus'}
# Processed : common_voice_br_17961889.mp3 => {'text': "perak emao o c'hoarzhin"}
# Processed : common_voice_br_17961890.mp3 => {'text': 'pever warn ugent'}
# Processed : common_voice_br_17961891.mp3 => {'text': 'mar pizh'}
# Processed : common_voice_br_18900754.mp3 => {'text': 'ur sikour telvoudus e vefe evito'}
# Processed : common_voice_br_18900755.mp3 => {'text': "pedarlugale ez eus skolietet d'en untadeut buezhek"}
# Processed : common_voice_br_18900756.mp3 => {'text': 'sdeuet e oa ar bitolz da ganañ'}
# Processed : common_voice_br_18900757.mp3 => {'text': 'disfiñ zo doa evel te a me'}
# Processed : common_voice_br_18900758.mp3 => {'text': 'bemañ a radio en e kreñva'}
# Processed : common_voice_br_37307629.mp3 => {'text': 'krogit enn ho hatlas eta ha al lennadenn vat'}
# Processed : common_voice_br_37307631.mp3 => {'text': "garbus ez a in d'ar skol hag a bred e rankenn sevel"}
# Processed : common_voice_br_37307632.mp3 => {'text': 'toret eo bet ar prenis kata'}
# Processed : common_voice_br_37307633.mp3 => {'text': 'tit kit'}
# Processed : common_voice_br_37307634.mp3 => {'text': 'ar brasañ aint'}
# Processed : common_voice_br_37623731.mp3 => {'text': "c'hwi a gar"}
# Processed : common_voice_br_37623732.mp3 => {'text': 'me a lennas'}
# Processed : common_voice_br_37623733.mp3 => {'text': "ar bizoù rin a vec'hkarront"}
# Processed : common_voice_br_37623734.mp3 => {'text': 'eañ a lenn'}
# Processed : common_voice_br_37623735.mp3 => {'text': 'ar pennad mañ divezhañ'}
# Processed : common_voice_br_29621038.mp3 => {'text': 'ul aotrelez gwad zicheg'}
# Processed : common_voice_br_29621040.mp3 => {'text': "penaos ne c'oarzhin ket pememp"}
# Processed : common_voice_br_29621042.mp3 => {'text': 'ezeut a ra din kenañ'}
# Processed : common_voice_br_29621045.mp3 => {'text': 'unan zet ha hanter kant'}
# Processed : common_voice_br_29621047.mp3 => {'text': 'nijet eo an lapoush kuit'}
# Processed : common_voice_br_41832795.mp3 => {'text': 'skriv dezhi ur postel a raok en emvelout'}
# Processed : common_voice_br_41832796.mp3 => {'text': 'diaochet en doa al leskl ha setuma oa er pelloù'}
# Processed : common_voice_br_41832797.mp3 => {'text': "n'eus ket moaien tennañ anezhañ er maez diouzhañ lec'hit"}
# Processed : common_voice_br_41832798.mp3 => {'text': 'marteze en oz or biken'}
# Processed : common_voice_br_41832799.mp3 => {'text': 'stanket eo an hent'}
# Processed : common_voice_br_42343906.mp3 => {'text': 'war raok yeaz ar frankizadur revel paodar bloaz vioù seiz kont'}
# Processed : common_voice_br_42343907.mp3 => {'text': "me n'eo ket gwall farzus"}
# Processed : common_voice_br_42343908.mp3 => {'text': 'penn aneizhañ'}
# Processed : common_voice_br_42343909.mp3 => {'text': 'laour'}
# Processed : common_voice_br_42343910.mp3 => {'text': "pokez plac'h ur poant galon ouzhpenn n'eus bet"}
# Processed : common_voice_br_32331762.mp3 => {'text': "gortozet hon eus a walc'h e vel se"}
# Processed : common_voice_br_32331763.mp3 => {'text': 'en ur goude anternoz'}
# Processed : common_voice_br_32331765.mp3 => {'text': 'ekstra'}
# Processed : common_voice_br_32331766.mp3 => {'text': 'sur out e karjer'}
# Processed : common_voice_br_32331768.mp3 => {'text': "erc'h a rae"}
# Processed : common_voice_br_28818620.mp3 => {'text': 'kañz a riz zo kanin'}
# Processed : common_voice_br_28818621.mp3 => {'text': 'selaouent'}
# Processed : common_voice_br_28818622.mp3 => {'text': 'gwell e daozenn gloazit heget unan last'}
# Processed : common_voice_br_28818623.mp3 => {'text': "un dazenn zogan war c'hoar"}
# Processed : common_voice_br_28818624.mp3 => {'text': 'ma div kador'}
# Processed : common_voice_br_38147014.mp3 => {'text': 'meo ingal din'}
# Processed : common_voice_br_38147015.mp3 => {'text': 'gwall nebeut a fichañs am eus enañ'}
# Processed : common_voice_br_38147016.mp3 => {'text': 'nag un arvest kaer'}
# Processed : common_voice_br_38147017.mp3 => {'text': "c'hoari a ra ganeomp"}
# Processed : common_voice_br_38147018.mp3 => {'text': 'gwelet e vo'}
# Processed : common_voice_br_37924584.mp3 => {'text': 'penas e vez aozet o bro gant ar vretoned'}
# Processed : common_voice_br_37924585.mp3 => {'text': "penaos douet deoc'h"}
# Processed : common_voice_br_37924586.mp3 => {'text': "n'out ket prest nann n'on ket"}
# Processed : common_voice_br_37924587.mp3 => {'text': 'un takad sur eo'}
# Processed : common_voice_br_37924588.mp3 => {'text': 'sportoureze deus afrika'}
# Processed : common_voice_br_40054916.mp3 => {'text': 'kas dint da labour de gwener an dibezhata'}
# Processed : common_voice_br_40054917.mp3 => {'text': "paze'm eus tapet"}
# Processed : common_voice_br_40054918.mp3 => {'text': 'an istorioù abdudezhi kalz'}
# Processed : common_voice_br_40054919.mp3 => {'text': 'ne oan ket sirius'}
# Processed : common_voice_br_40054920.mp3 => {'text': 'ne gemet es ket da tebegedioù abatroù'}
# Processed : common_voice_br_38884586.mp3 => {'text': 'distro ar feulster'}
# Processed : common_voice_br_38884587.mp3 => {'text': 'ur piana en deus prenet dezhi ur sapretaat ma lavar din'}
# Processed : common_voice_br_38884588.mp3 => {'text': 're wir eo'}
# Processed : common_voice_br_38884589.mp3 => {'text': 'sell ouzh al lampan bihan mañ'}
# Processed : common_voice_br_38884590.mp3 => {'text': 'daon evel bravañ al lennegezh alamaneg eo'}
# Processed : common_voice_br_38157065.mp3 => {'text': "da c'hoar a garan"}
# Processed : common_voice_br_38157066.mp3 => {'text': "komzañ a rae eus e c'hoar ed deouzh vroall da labourat"}
# Processed : common_voice_br_38157067.mp3 => {'text': 'tapet an deus e vlaz warn ugent'}
# Processed : common_voice_br_38157068.mp3 => {'text': 'tremenet e dre e azel'}
# Processed : common_voice_br_38157069.mp3 => {'text': 'kredet ema an nichekanet'}
# Processed : common_voice_br_21445929.mp3 => {'text': 'klav puizh zo bet icho'}
# Processed : common_voice_br_21445930.mp3 => {'text': "sur on e karzec'h"}
# Processed : common_voice_br_21445931.mp3 => {'text': "a c'hedon"}
# Processed : common_voice_br_21445932.mp3 => {'text': 'chom a raye ken echelaour'}
# Processed : common_voice_br_21445933.mp3 => {'text': 'ur potr bras'}
# Processed : common_voice_br_17766803.mp3 => {'text': 'cheñchamant o bras zo bet'}
# Processed : common_voice_br_17766805.mp3 => {'text': 'urgador all'}
# Processed : common_voice_br_17766807.mp3 => {'text': 'un tregont dezem bennak'}
# Processed : common_voice_br_17766843.mp3 => {'text': 'arabat dont emañ'}
# Processed : common_voice_br_17766845.mp3 => {'text': "ar pal a oa mont da bec'h abeure pa vez un tamm muioc'h a amzer gant familhoù zosañse"}
# Processed : common_voice_br_17766847.mp3 => {'text': 'an trede diwezhañ'}
# Processed : common_voice_br_41849758.mp3 => {'text': 'ha komprenet ho peus an holl draoù se'}
# Processed : common_voice_br_41849759.mp3 => {'text': 'hur ma doue pegen kaver'}
# Processed : common_voice_br_41901433.mp3 => {'text': "trist'm eus e gavet ha c'hoz anezo marteze"}
# Processed : common_voice_br_41901434.mp3 => {'text': "er c'harnij e dromp paz eo kroget kleñvet dadad"}
# Processed : common_voice_br_41901435.mp3 => {'text': 'brav e oa ar paoltreds'}
# Processed : common_voice_br_41901436.mp3 => {'text': 'ar fakturenn a zo aet re gozh setu tout'}
# Processed : common_voice_br_41901437.mp3 => {'text': 'diskenn ar ri duchantig'}
# Processed : common_voice_br_17965067.mp3 => {'text': 'un dra gereama hi'}
# Processed : common_voice_br_17965068.mp3 => {'text': "an triwec'hvit"}
# Processed : common_voice_br_17965069.mp3 => {'text': 'ar voest lizer ou'}
# Processed : common_voice_br_17965070.mp3 => {'text': 'yen eo an amzer'}
# Processed : common_voice_br_17965071.mp3 => {'text': 'unnek'}
# Processed : common_voice_br_17972514.mp3 => {'text': 'deboant a reot un doa bennak all'}
# Processed : common_voice_br_17972515.mp3 => {'text': 'kalz lebour am eus'}
# Processed : common_voice_br_17972516.mp3 => {'text': 'yen ki eo'}
# Processed : common_voice_br_17974786.mp3 => {'text': "gallout a ran ampresta un tamm arc'hanv"}
# Processed : common_voice_br_17974788.mp3 => {'text': 'kêr ar gelvenneg'}
# Processed : common_voice_br_17974789.mp3 => {'text': 'petra e volus kar chanter'}
# Processed : common_voice_br_17974790.mp3 => {'text': 'hon daouanv'}
# Processed : common_voice_br_17974791.mp3 => {'text': 'evel se emañ an traoù'}
# Processed : common_voice_br_17974792.mp3 => {'text': "ma pesketfec'h"}
# Processed : common_voice_br_17974793.mp3 => {'text': "mal oz c'huzh war ar skipailh a vo trec'het atav"}
# Processed : common_voice_br_17974794.mp3 => {'text': 'piv zo deuet'}
# Processed : common_voice_br_17974795.mp3 => {'text': 'te eo'}
# Processed : common_voice_br_18143084.mp3 => {'text': "hemmet da c'heiñ"}
# Processed : common_voice_br_18143085.mp3 => {'text': 're well ho po'}
# Processed : common_voice_br_18143088.mp3 => {'text': "ene'mp zaol tri darle"}
# Processed : common_voice_br_18143091.mp3 => {'text': 'beuet eo bet hir mor'}
# Processed : common_voice_br_18143092.mp3 => {'text': "e c'hêrioù"}
# Processed : common_voice_br_18143093.mp3 => {'text': 'migare eo implijet un geñvrwedat'}
# Processed : common_voice_br_18143094.mp3 => {'text': "o ta ket in direinko c'hanoc'h"}
# Processed : common_voice_br_18143095.mp3 => {'text': "oant eo miji de gavout an emgar geneoc'h evit meur ar raktres"}
# Processed : common_voice_br_18143096.mp3 => {'text': 'kentañ tro o teilad hamañ lavar din a raok'}
# Processed : common_voice_br_20928281.mp3 => {'text': "arabat d'eog mont di"}
# Processed : common_voice_br_21388890.mp3 => {'text': 'ni ag ara'}
# Processed : common_voice_br_21388892.mp3 => {'text': "n'ouzer ket"}
# Processed : common_voice_br_21388893.mp3 => {'text': 'penaos en em denezh'}
# Processed : common_voice_br_21388910.mp3 => {'text': "ar pep gwellan eo d'obereñ"}
# Processed : common_voice_br_21388911.mp3 => {'text': 'dugenn breizh'}
# Processed : common_voice_br_21388912.mp3 => {'text': 'trizi'}
# Processed : common_voice_br_21388913.mp3 => {'text': 'ti al louarnañ'}
# Processed : common_voice_br_21388914.mp3 => {'text': "prenan an noc'h"}
# Processed : common_voice_br_18646704.mp3 => {'text': 'pet e oa al leer en ti hem na vechien pet e unet'}
# Processed : common_voice_br_18646705.mp3 => {'text': 'ya'}
# Processed : common_voice_br_18646706.mp3 => {'text': "krediñ a ran ac'hanoc'h"}
# Processed : common_voice_br_18646707.mp3 => {'text': 'digeriñ a ra an nor'}
# Processed : common_voice_br_18646709.mp3 => {'text': 'rankout a ra kompren'}
# Processed : common_voice_br_18646710.mp3 => {'text': "kig az po c'hoazh"}
# Processed : common_voice_br_18646711.mp3 => {'text': 'unan hag hanter kant'}
# Processed : common_voice_br_18646712.mp3 => {'text': 'den ebet'}
# Processed : common_voice_br_18646713.mp3 => {'text': "ne vo den ebet er burev warc'hoazh"}
# Processed : common_voice_br_19446746.mp3 => {'text': "hn'eus ket bet anv e laezhfe e blas dezhe gwech ebet"}
# Processed : common_voice_br_19446747.mp3 => {'text': "ata ta trona un digarezit e nezegemeronp ket nemet arc'hant losk"}
# Processed : common_voice_br_19446748.mp3 => {'text': 'ne ra nemet klemmaet an daez'}
# Processed : common_voice_br_19446749.mp3 => {'text': 'graet eo ar gwestel gant bleud a vio'}
# Processed : common_voice_br_19446750.mp3 => {'text': 'uñ avliennoùiga'}
# Processed : common_voice_br_19446751.mp3 => {'text': 'a da lenter kozums dit ul loaiad hanter eo'}
# Processed : common_voice_br_19446752.mp3 => {'text': "hun digarezit nezek eman ket ar c'hartenn ho kred"}
# Processed : common_voice_br_19446753.mp3 => {'text': 'an oab zo glas muia'}
# Processed : common_voice_br_19446755.mp3 => {'text': "en dro d'ar brasañc"}
# Processed : common_voice_br_32330618.mp3 => {'text': "pemitee da' ur skol gac'had"}
# Processed : common_voice_br_32330619.mp3 => {'text': 'ur gwarnak ganañ yez e vevañ'}
# Processed : common_voice_br_32330620.mp3 => {'text': "faotay ra deoc'h"}
# Processed : common_voice_br_32330621.mp3 => {'text': 'nebeut deor nabad a dud a ra an dra sa'}
# Processed : common_voice_br_32330622.mp3 => {'text': "pa c'hloazh eo ni  c'hoar a veliat holl gwall zarvoud"}
# Processed : common_voice_br_32330630.mp3 => {'text': 'ma eklagouie petra e oll'}
# Processed : common_voice_br_32330631.mp3 => {'text': 'un istouere gwir'}
# Processed : common_voice_br_32330633.mp3 => {'text': 'hi a gara'}
# Processed : common_voice_br_32330635.mp3 => {'text': 'karot a rae ma mam a pe de egelet'}
# Processed : common_voice_br_21385093.mp3 => {'text': "blañset e oa bet orc'h enem ganañ gant bugale all"}
# Processed : common_voice_br_21385124.mp3 => {'text': 'pegement eo se'}
# Processed : common_voice_br_21385125.mp3 => {'text': 'marvet eo da eunnek eur marv eo'}
# Processed : common_voice_br_21385126.mp3 => {'text': 'nag e dismant'}
# Processed : common_voice_br_21385137.mp3 => {'text': 'karet ho peus'}
# Processed : common_voice_br_21385138.mp3 => {'text': 'pegeit e chomot'}
# Processed : common_voice_br_21385139.mp3 => {'text': 'ur froezenn bennak en deus debret da goan'}
# Processed : common_voice_br_21385140.mp3 => {'text': 'emañ mala ho kontañ en istor'}
# Processed : common_voice_br_21385141.mp3 => {'text': "n'eus karet bet war reblanent"}
# Processed : common_voice_br_19308074.mp3 => {'text': "aet eo da skihañ ha tore n eus e c'harr"}
# Processed : common_voice_br_19308075.mp3 => {'text': "em c'hannv"}
# Processed : common_voice_br_19308076.mp3 => {'text': 'aon doa bet'}
# Processed : common_voice_br_19308077.mp3 => {'text': "tebret deus laeizh ho c'hof"}
# Processed : common_voice_br_19308078.mp3 => {'text': "skoet eo bet ma c'harr gant ur c'harall"}
# Processed : common_voice_br_19308099.mp3 => {'text': 'an nevesañ aneze'}
# Processed : common_voice_br_19308100.mp3 => {'text': 'karet on bet'}
# Processed : common_voice_br_19308101.mp3 => {'text': 'tregeri sogoaperien'}
# Processed : common_voice_br_19308102.mp3 => {'text': "ar c'hozh ac'hanon"}
# Processed : common_voice_br_19308103.mp3 => {'text': 'kadorioù melen bras allv'}
# Processed : common_voice_br_18081133.mp3 => {'text': "c'he vras eo"}
# Processed : common_voice_br_18081134.mp3 => {'text': "on a raiop d'ar sinema maar bezh amzer"}
# Processed : common_voice_br_18081135.mp3 => {'text': 'meus poston eo ho kaz ivez'}
# Processed : common_voice_br_18081136.mp3 => {'text': 'krediñ a ranne ze int ket'}
# Processed : common_voice_br_18081137.mp3 => {'text': 'me graet e teunt holl'}
# Processed : common_voice_br_18081143.mp3 => {'text': "'ont ke niet bras eo you unanat deoc'h"}
# Processed : common_voice_br_18081144.mp3 => {'text': 'eseit kêr eo bet an traoù'}
# Processed : common_voice_br_18081145.mp3 => {'text': 'monat a bet hi an dud'}
# Processed : common_voice_br_18081146.mp3 => {'text': 'int eo'}
# Processed : common_voice_br_18081147.mp3 => {'text': 'skol montroulez'}
# Processed : common_voice_br_23892735.mp3 => {'text': 'nann'}
# Processed : common_voice_br_23892736.mp3 => {'text': 'daour'}
# Processed : common_voice_br_23892737.mp3 => {'text': 'tre'}
# Processed : common_voice_br_23892738.mp3 => {'text': 'nav'}
# Processed : common_voice_br_23892739.mp3 => {'text': "per'"}
# Processed : common_voice_br_23892770.mp3 => {'text': 'man'}
# Processed : common_voice_br_23892771.mp3 => {'text': "orc'h"}
# Processed : common_voice_br_23892772.mp3 => {'text': 'pemp'}
# Processed : common_voice_br_23892773.mp3 => {'text': 'ya'}
# Processed : common_voice_br_23892774.mp3 => {'text': 'e unan'}
# Processed : common_voice_br_27160024.mp3 => {'text': 'bremaik ur boemgav ganto'}
# Processed : common_voice_br_27160025.mp3 => {'text': 'da biv eo'}
# Processed : common_voice_br_27160026.mp3 => {'text': 'da gambr'}
# Processed : common_voice_br_27160027.mp3 => {'text': 'ma skouzit gantañ'}
# Processed : common_voice_br_27160028.mp3 => {'text': 'hag evel se eo e vez skolet amzer'}
# Processed : common_voice_br_27160039.mp3 => {'text': "pelec'h emañ on disheurtou"}
# Processed : common_voice_br_27160040.mp3 => {'text': "ma'hoc'h eus nemet ouzhpennañ al lizherennoù ober"}
# Processed : common_voice_br_27160041.mp3 => {'text': 'pet aotr eus eo an hent'}
# Processed : common_voice_br_27160042.mp3 => {'text': 'hed eo eo'}
# Processed : common_voice_br_27160043.mp3 => {'text': 'un dra bennak anevez'}
# Processed : common_voice_br_42807655.mp3 => {'text': 'ke kuit'}
# Processed : common_voice_br_42807656.mp3 => {'text': "met seul varekoc'h ar benveg seul geêr hoc'h ivez"}
# Processed : common_voice_br_42807657.mp3 => {'text': "c'hoant en dez voe lavarout un dra bennak"}
# Processed : common_voice_br_42807658.mp3 => {'text': 'kaozh eo ar vilhin se'}
# Processed : common_voice_br_42807659.mp3 => {'text': 'me fiziañs am eus hon eus pep a en da heuliañ'}
# Processed : common_voice_br_42807660.mp3 => {'text': 'an aval zo ruz ru eo an aval'}
# Processed : common_voice_br_42807661.mp3 => {'text': 'ur gwallzarvoud a vefe a respant ar prezidant'}
# Processed : common_voice_br_42807662.mp3 => {'text': 'rann divoret ul lestr'}
# Processed : common_voice_br_42807663.mp3 => {'text': 'eizh ha tri ugent'}
# Processed : common_voice_br_42807664.mp3 => {'text': "neuze en emsantek gwelloc'h"}
# Processed : common_voice_br_18015225.mp3 => {'text': "e c'hani"}
# Processed : common_voice_br_18015237.mp3 => {'text': 'perak kaozh greitson'}
# Processed : common_voice_br_18015240.mp3 => {'text': 'a zebreshioe'}
# Processed : common_voice_br_18015241.mp3 => {'text': 'predet moui ur rochi der'}
# Processed : common_voice_br_18015249.mp3 => {'text': 'rin alta'}
# Processed : common_voice_br_18015252.mp3 => {'text': "un tuzarwec'h boued"}
# Processed : common_voice_br_18015255.mp3 => {'text': 'deus ar re koan'}
# Processed : common_voice_br_18015256.mp3 => {'text': "poent'm eus e kredain ar per a zispeditain"}
# Processed : common_voice_br_18015263.mp3 => {'text': 'purhlitrad gwin'}
# Processed : common_voice_br_18015266.mp3 => {'text': "c'hwec'h e deu da vout"}
# Processed : common_voice_br_18015272.mp3 => {'text': 'mer pegeit e vot amañ'}
# Processed : common_voice_br_18008266.mp3 => {'text': 'beit ouzh taol'}
# Processed : common_voice_br_18008271.mp3 => {'text': 'an daou velañ skipailh eo'}
# Processed : common_voice_br_18008275.mp3 => {'text': 'peitr an noten'}
# Processed : common_voice_br_18008278.mp3 => {'text': "n'eus den eno evit poent"}
# Processed : common_voice_br_18008294.mp3 => {'text': "an dra man n'eo ket ur c'hion"}
# Processed : common_voice_br_18008295.mp3 => {'text': 'an ti kerañ'}
# Processed : common_voice_br_18008296.mp3 => {'text': 'disoñjit an tremened'}
# Processed : common_voice_br_18008298.mp3 => {'text': 'ne gomprenent seurt'}
# Processed : common_voice_br_21480348.mp3 => {'text': 'an tiez melenañ'}
# Processed : common_voice_br_21480349.mp3 => {'text': "petra yay ganeoc'h"}
# Processed : common_voice_br_21480351.mp3 => {'text': 'hemañ eo a blij din añ muiañ'}
# Processed : common_voice_br_21480353.mp3 => {'text': "digeriñ a ri d'an nor"}
# Processed : common_voice_br_18169585.mp3 => {'text': 'ronañ hag a oa klañv a chom a zergeveziveozya'}
# Processed : common_voice_br_18169586.mp3 => {'text': "n'haller ket dont a benn eus netra pa vez zer nec'het evel se"}
# Processed : common_voice_br_18169587.mp3 => {'text': "pevar c'hoari da denus warn ugentat"}
# Processed : common_voice_br_18169588.mp3 => {'text': 'ar skiantoù denel'}
# Processed : common_voice_br_18169590.mp3 => {'text': 'da amañ eo'}
# Processed : common_voice_br_18169592.mp3 => {'text': "pe hini o ar marc'hadmat ta"}
# Processed : common_voice_br_18169593.mp3 => {'text': 'en armel'}
# Processed : common_voice_br_18169594.mp3 => {'text': "ar gouin mañ n'eo ket koulz hag egile"}
# Processed : common_voice_br_18169600.mp3 => {'text': 'krefhin da pin'}
# Processed : common_voice_br_18169601.mp3 => {'text': 'emañ ra vi ho kanañ ur ganaouad'}
# Processed : common_voice_br_18169602.mp3 => {'text': "sec'hed azh peus"}
# Processed : common_voice_br_18169603.mp3 => {'text': 'estreget gouzañ e v ez o bevañ'}
# Processed : common_voice_br_18169604.mp3 => {'text': "gallout a rit kavout ac'hanomp"}
# Processed : common_voice_br_17402828.mp3 => {'text': "perak ne zifenn ket frañs aliesseurtet zo enni ec'h unan"}
# Processed : common_voice_br_17402830.mp3 => {'text': 'pea rin'}
# Processed : common_voice_br_17402831.mp3 => {'text': "da c'hoar a garen"}
# Processed : common_voice_br_17402832.mp3 => {'text': "hag ur plac'h oc'h"}
# Processed : common_voice_br_17402833.mp3 => {'text': "ar plac'h se a dri d'e c'halon"}
# Processed : common_voice_br_17402834.mp3 => {'text': 'degemer a rit dollaroù e sur'}
# Processed : common_voice_br_17402835.mp3 => {'text': 'an dei pad'}
# Processed : common_voice_br_17402836.mp3 => {'text': "moc'h ezomp da vezañ skoazellet levri din"}
# Processed : common_voice_br_17402837.mp3 => {'text': 'peseurt ket fredi ouzhpenn zo gantañ nive'}
# Processed : common_voice_br_17402838.mp3 => {'text': 'o breuder'}
# Processed : common_voice_br_17402839.mp3 => {'text': 'hon dorn'}
# Processed : common_voice_br_17402840.mp3 => {'text': 'nann'}
# Processed : common_voice_br_17402841.mp3 => {'text': "tre c'hi"}
# Processed : common_voice_br_17402842.mp3 => {'text': "peseurt anoc'h euz"}
# Processed : common_voice_br_17982366.mp3 => {'text': 'aet e oa ma mamm da an an war lenne'}
# Processed : common_voice_br_17982367.mp3 => {'text': "da noz e klevemp a raned o c'hakal"}
# Processed : common_voice_br_17982369.mp3 => {'text': 'ar skipailh gwellañ'}
# Processed : common_voice_br_17982370.mp3 => {'text': 'petra a slefenn gwiskeñ'}
# Processed : common_voice_br_17982372.mp3 => {'text': 'an dud a blij invezhañ ganto azo tud diardoù'}
# Processed : common_voice_br_17982373.mp3 => {'text': 'ne bren ket ma zad ar gazetenn er stal bemdez'}
# Processed : common_voice_br_17982374.mp3 => {'text': 'skuizh kenañon'}
# Processed : common_voice_br_17982375.mp3 => {'text': "tapet e vo mac'ht anavez ar boliserien anezhañ"}
# Processed : common_voice_br_17982376.mp3 => {'text': 'sevel a re rhento kont pizh'}
# Processed : common_voice_br_17982377.mp3 => {'text': 'pezh e oa'}
# Processed : common_voice_br_17982378.mp3 => {'text': 'deuit amañ an hollenn din mar plij'}
# Processed : common_voice_br_17982379.mp3 => {'text': 'ma z eus kutennoù eo reden lavaret'}
# Processed : common_voice_br_17982380.mp3 => {'text': 'an holl vugale'}
# Processed : common_voice_br_18005706.mp3 => {'text': "da c'hoar a garet"}
# Processed : common_voice_br_18005707.mp3 => {'text': "kouezhet e'm eus en ur glask kêrzhet war un troadep keñ"}
# Processed : common_voice_br_18005708.mp3 => {'text': 'em ye'}
# Processed : common_voice_br_18005709.mp3 => {'text': "komzet em eus gant paotr an diwalerezh kavout a rent e rae nebeutoc'h a familioù gwelet"}
# Processed : common_voice_br_18005710.mp3 => {'text': 'ur mog eo'}
# Processed : common_voice_br_18005711.mp3 => {'text': 'treizh en oz'}
# Processed : common_voice_br_18005712.mp3 => {'text': "ne viot c'hwi ket gwelet oc'h ober war dro ar vugale"}
# Processed : common_voice_br_18005713.mp3 => {'text': 'eiz plas'}
# Processed : common_voice_br_18005714.mp3 => {'text': 'goulout a ra mat'}
# Processed : common_voice_br_18005715.mp3 => {'text': 'ar gargadeñ zord'}
# Processed : common_voice_br_18006492.mp3 => {'text': 'hon breuder'}
# Processed : common_voice_br_18006494.mp3 => {'text': "petra emaoc'h hoc'h oder"}
# Processed : common_voice_br_18006495.mp3 => {'text': "gwelit'm eus ar c'hi neardrezi an hent"}
# Processed : common_voice_br_18006496.mp3 => {'text': 'daou boen lañs'}
# Processed : common_voice_br_43421379.mp3 => {'text': 'eus brest on'}
# Processed : common_voice_br_43421403.mp3 => {'text': 'gallout a rik lakat an asiedoù e ganastel en dro'}
# Processed : common_voice_br_43421404.mp3 => {'text': 'spluj aa zeskouer mor ruz'}
# Processed : common_voice_br_43421405.mp3 => {'text': "ne oent ket da zindan zivin n'o doa nemet ar marv d'a c'hortoz"}
# Processed : common_voice_br_43421407.mp3 => {'text': "seul dommar seul blijusoc'h"}
# Processed : common_voice_br_43427157.mp3 => {'text': 'pegoulz emañ an dimeze'}
# Processed : common_voice_br_43427158.mp3 => {'text': 'me eo ar brasañ'}
# Processed : common_voice_br_43427160.mp3 => {'text': "chwec'h eo"}
# Processed : common_voice_br_43427168.mp3 => {'text': 'ma unan penn e wen'}
# Processed : common_voice_br_43427170.mp3 => {'text': "gant m'en em gavo e koulz"}
# Processed : common_voice_br_43427344.mp3 => {'text': "c'hwec'h eu ar vintin anezho"}
# Processed : common_voice_br_43427345.mp3 => {'text': "biskouar n'e'm eus c'hoarzhet kement all"}
# Processed : common_voice_br_43427347.mp3 => {'text': 'an dremeniri zo bras'}
# Processed : common_voice_br_43427348.mp3 => {'text': 'stlakaet e vez an daouarn para traoù kaer'}
# Processed : common_voice_br_17963237.mp3 => {'text': 'ar goulenn pouezus'}
# Processed : common_voice_br_17963238.mp3 => {'text': 'da lun neveztigor'}
# Processed : common_voice_br_17963239.mp3 => {'text': 'er bleuz mañ'}
# Processed : common_voice_br_17963240.mp3 => {'text': "komzer un ganeoc'h a raok pell"}
# Processed : common_voice_br_17963241.mp3 => {'text': 'ouzh t aoll'}
# Processed : common_voice_br_17964721.mp3 => {'text': 'eizh warn ugent'}
# Processed : common_voice_br_17964722.mp3 => {'text': 'ar reruz'}
# Processed : common_voice_br_17964723.mp3 => {'text': 'peni'}
# Processed : common_voice_br_17964724.mp3 => {'text': 'poent benn am eus'}
# Processed : common_voice_br_17964726.mp3 => {'text': 'brav en amzer'}
# Processed : common_voice_br_17964767.mp3 => {'text': 'fellout a ra dezhi'}
# Processed : common_voice_br_17964768.mp3 => {'text': "krev n uzo ganeoc'h"}
# Processed : common_voice_br_17964769.mp3 => {'text': 'un ti nevez em eus'}
# Processed : common_voice_br_17964770.mp3 => {'text': 're ger eo'}
# Processed : common_voice_br_18063022.mp3 => {'text': 'ar svodern eo ar gubouriezh'}
# Processed : common_voice_br_18063024.mp3 => {'text': 'karet hon eus'}
# Processed : common_voice_br_18063090.mp3 => {'text': "er c'hwoell c'hoantoù"}
# Processed : common_voice_br_18063092.mp3 => {'text': 'peseurt atresoù skolioù nevez zo evit ar bloavezhioù ganzont'}
# Processed : common_voice_br_18063093.mp3 => {'text': "unetad varc'hanm emaon"}
# Processed : common_voice_br_18063094.mp3 => {'text': "am kast a rann war lec'h an ti post"}
# Processed : common_voice_br_18079723.mp3 => {'text': 'pellgomzin din mar plij'}
# Processed : common_voice_br_18079724.mp3 => {'text': "pegoulz oc'h en em gavet e boston"}
# Processed : common_voice_br_18079726.mp3 => {'text': 'dispar eo'}
# Processed : common_voice_br_18079812.mp3 => {'text': 'labourat mat a ra in'}
# Processed : common_voice_br_18079813.mp3 => {'text': "ravo c'hoar zo"}
# Processed : common_voice_br_18079814.mp3 => {'text': "a benn warc'hoazh e vo echu ganeoc'h strivañ"}
# Processed : common_voice_br_18079815.mp3 => {'text': 'skouet en eul se droad en nor'}
# Processed : common_voice_br_18079816.mp3 => {'text': 'karet on'}
# Processed : common_voice_br_19352122.mp3 => {'text': "n'e'm eus ket klevet tra diwar benn abae emaoc'h skrivet dinmes zo"}
# Processed : common_voice_br_19352123.mp3 => {'text': "her c'higni zo anañ"}
# Processed : common_voice_br_19352124.mp3 => {'text': 'plen ha kompes'}
# Processed : common_voice_br_22472044.mp3 => {'text': "n'eus den ebet"}
# Processed : common_voice_br_22472045.mp3 => {'text': "pelec'h emañ ma levrioù"}
# Processed : common_voice_br_22472046.mp3 => {'text': 'an dud skouezt a gwachañ'}
# Processed : common_voice_br_22472047.mp3 => {'text': "d'ar mare ma oant tigerian nor"}
# Processed : common_voice_br_22472048.mp3 => {'text': 'kant on landerne'}
# Processed : common_voice_br_32236535.mp3 => {'text': 'o dorn'}
# Processed : common_voice_br_32236536.mp3 => {'text': 'dek'}
# Processed : common_voice_br_32236537.mp3 => {'text': 'kemernt mañ va lavaret'}
# Processed : common_voice_br_32236538.mp3 => {'text': "ar c'hentañ skoliad eus e glas eo boulvenn"}
# Processed : common_voice_br_32236539.mp3 => {'text': 'ar gwir zo gantañ'}
# Processed : common_voice_br_17973149.mp3 => {'text': "kadud ar bezh zo merket er c'haier"}
# Processed : common_voice_br_17973151.mp3 => {'text': 'en em ganañ'}
# Processed : common_voice_br_17973152.mp3 => {'text': 'leunit anezhañ mar blij'}
# Processed : common_voice_br_17973153.mp3 => {'text': 'ho pezid soñj'}
# Processed : common_voice_br_17973154.mp3 => {'text': "petra hoc'h eus c'hoant d'ober en degouezh mañ"}
# Processed : common_voice_br_17973155.mp3 => {'text': 'ne deuio ket pa za o klañv'}
# Processed : common_voice_br_17973156.mp3 => {'text': "an archer a welet ac'hanon"}
# Processed : common_voice_br_17973157.mp3 => {'text': 'tapout a rin henez ivez'}
# Processed : common_voice_br_17973158.mp3 => {'text': 'hen zo bet garet'}
# Processed : common_voice_br_17973159.mp3 => {'text': 'tomm gar eo'}
# Processed : common_voice_br_17973160.mp3 => {'text': "sgoret eobet an nor ganeoc'h"}
# Processed : common_voice_br_17973161.mp3 => {'text': 'ar gevr'}
# Processed : common_voice_br_17973162.mp3 => {'text': 'o levr du'}
# Processed : common_voice_br_17973163.mp3 => {'text': 'karet e eus'}
# Processed : common_voice_br_37416683.mp3 => {'text': 'kaz bloavh eo es redek anaouenn'}
# Processed : common_voice_br_37416685.mp3 => {'text': 'eus mouchavel ebet er mintin mañ'}
# Processed : common_voice_br_37416686.mp3 => {'text': "gant ur c'hreion reuz e kechis ar respont mat"}
# Processed : common_voice_br_37416687.mp3 => {'text': "petra hoc'h eus glaet"}
# Processed : common_voice_br_37416695.mp3 => {'text': 'mond er nag emper'}
# Processed : common_voice_br_37416698.mp3 => {'text': 'azezit mar plij'}
# Processed : common_voice_br_37416700.mp3 => {'text': 'un dra vat kenañ'}
# Processed : common_voice_br_37416701.mp3 => {'text': 'ur gelennerez gallek'}
# Processed : common_voice_br_37416702.mp3 => {'text': 'ma bleudel enem gane ket netraeze'}
# Processed : common_voice_br_37416723.mp3 => {'text': 'loz eo'}
# Processed : common_voice_br_37416724.mp3 => {'text': 'keluntezus tre eo ma mamm'}
# Processed : common_voice_br_37416725.mp3 => {'text': "hi 'n deus karet"}
# Processed : common_voice_br_37416726.mp3 => {'text': 'bezeknout aan eurj'}
# Processed : common_voice_br_37416727.mp3 => {'text': "da c'hoar egarjen"}
# Processed : common_voice_br_17966480.mp3 => {'text': "me ag arfe gouzout da bez e vo diskrog labour warc'hoazh"}
# Processed : common_voice_br_17966481.mp3 => {'text': 'mann'}
# Processed : common_voice_br_17966482.mp3 => {'text': "pelec'h hoc'h eus desket se"}
# Processed : common_voice_br_17966483.mp3 => {'text': 'gelout a ran komz graet an intron varez'}
# Processed : common_voice_br_17966484.mp3 => {'text': "ne gleven ket ar c'hloc'h"}
# Processed : common_voice_br_17966485.mp3 => {'text': 'un dorzh vara'}
# Processed : common_voice_br_17966486.mp3 => {'text': 'ma vijes anezho'}
# Processed : common_voice_br_17966487.mp3 => {'text': 'pegoulz ema dazont'}
# Processed : common_voice_br_17966488.mp3 => {'text': 'mont a reas da guz evit pas bezañ gourdrozet'}
# Processed : common_voice_br_17966489.mp3 => {'text': 'petra eo labour pennañ an dud eno'}
# Processed : common_voice_br_17966490.mp3 => {'text': 'hini ebet eus ar re se'}
# Processed : common_voice_br_17966491.mp3 => {'text': 'pe naouzer ket an unan'}
# Processed : common_voice_br_17966492.mp3 => {'text': 'te a garo'}
# Processed : common_voice_br_17966493.mp3 => {'text': "ni zo daou vreur hag ho c'hoar er gêr"}
# Processed : common_voice_br_17966494.mp3 => {'text': "e korfer miz e c'haller diskar petra"}
# Processed : common_voice_br_43421167.mp3 => {'text': 'pell eo'}
# Processed : common_voice_br_43421168.mp3 => {'text': 'graet eo gantezo marevezh ur marevezh mat'}
# Processed : common_voice_br_43421169.mp3 => {'text': 'kroget eo ar politikerez evit gwellaat ar getvuhez'}
# Processed : common_voice_br_43421170.mp3 => {'text': 'goude al labourioù e vo en e vakañsoù'}
# Processed : common_voice_br_43421171.mp3 => {'text': "pi wec'h vugalez eo"}
# Processed : common_voice_br_43421172.mp3 => {'text': "lavaret a ra e plij deoc'h sellet ouzhfinioñ"}
# Processed : common_voice_br_43421173.mp3 => {'text': 'en dra vat e ober'}
# Processed : common_voice_br_43421174.mp3 => {'text': "un taol mor diwar ur gareg ret eo deont pellat ac'han"}
# Processed : common_voice_br_43421175.mp3 => {'text': 'u puen oa lavaret'}
# Processed : common_voice_br_43421176.mp3 => {'text': "ha deuet on d'an ur vat"}
# Processed : common_voice_br_43421182.mp3 => {'text': 'prestink da vont en dro'}
# Processed : common_voice_br_43421183.mp3 => {'text': 'div gand faz zo'}
# Processed : common_voice_br_43421184.mp3 => {'text': 'ogen cheñch a ran traoù'}
# Processed : common_voice_br_43421185.mp3 => {'text': 'a raok dezhañ zo ken'}
# Processed : common_voice_br_43421186.mp3 => {'text': 'e brezhoneg evel just'}
# Processed : common_voice_br_40054936.mp3 => {'text': 'ledou a veze graeet eus breizh gwechall'}
# Processed : common_voice_br_40054937.mp3 => {'text': 'ledroul ouz eo bet a raok se e kontmetrad'}
# Processed : common_voice_br_40054938.mp3 => {'text': 'mojeno broleout zo ese patav'}
# Processed : common_voice_br_40054939.mp3 => {'text': "ya solut 'ar guzenn"}
# Processed : common_voice_br_40054940.mp3 => {'text': "bisoñjet c' eus an tomatez"}
# Processed : common_voice_br_40055074.mp3 => {'text': 'div a lakaom raoul'}
# Processed : common_voice_br_40055075.mp3 => {'text': 'kelet sutel'}
# Processed : common_voice_br_40055076.mp3 => {'text': 'prena da fourk'}
# Processed : common_voice_br_40055077.mp3 => {'text': 'nebaouez eom ket da zibi ur saprepred familhv'}
# Processed : common_voice_br_40055078.mp3 => {'text': "n'ouz ket amzer walc'h"}
# Processed : common_voice_br_40055079.mp3 => {'text': "gouzalc'het gant soudaded"}
# Processed : common_voice_br_40055080.mp3 => {'text': 'piv a gemero seurt dreskloù'}
# Processed : common_voice_br_40055081.mp3 => {'text': 'ar revluskaioù goredeln kegun saotrus an deizivier'}
# Processed : common_voice_br_40055082.mp3 => {'text': "ul no so den deus ep pla'h an ivin"}
# Processed : common_voice_br_40055083.mp3 => {'text': "kejet m eus gant henaen dec'h ha paotplijus"}
# Processed : common_voice_br_41828052.mp3 => {'text': 'ha gri pezeurt ganink'}
# Processed : common_voice_br_41828053.mp3 => {'text': "n'o ket bout ken micha"}
# Processed : common_voice_br_41828054.mp3 => {'text': 'pouezh a bihn war an tam'}
# Processed : common_voice_br_41828055.mp3 => {'text': 'petra a vu kaozh ha ne respontet ket'}
# Processed : common_voice_br_41828180.mp3 => {'text': 'ar mo zo bet graet'}
# Processed : common_voice_br_41828181.mp3 => {'text': 'piv a raeo al labour'}
# Processed : common_voice_br_41828182.mp3 => {'text': 'ne vin ket pell ken'}
# Processed : common_voice_br_41828183.mp3 => {'text': 'da bleu eo da kas'}
# Processed : common_voice_br_41828184.mp3 => {'text': 'istorioù za dar kontañ'}
# Processed : common_voice_br_41828259.mp3 => {'text': 'penaos ta'}
# Processed : common_voice_br_41828260.mp3 => {'text': 'ar bouedel zo chom ee se'}
# Processed : common_voice_br_41828261.mp3 => {'text': "n'ober ket droald kaozeiñ brezhoneg"}
# Processed : common_voice_br_41828262.mp3 => {'text': "miskoazh c'hoazh"}
# Processed : common_voice_br_41828263.mp3 => {'text': "n'aon ket sur deuz ar respont"}
# Processed : common_voice_br_22694536.mp3 => {'text': 'brudet an'}
# Processed : common_voice_br_22694538.mp3 => {'text': 'bras eo an ti'}
# Processed : common_voice_br_22694540.mp3 => {'text': 'mont a rann da goanañ'}
# Processed : common_voice_br_22694621.mp3 => {'text': 'ouzhpenn chas e oa o yudal'}
# Processed : common_voice_br_22694623.mp3 => {'text': "'ma ket ganit"}
# Processed : common_voice_br_22694624.mp3 => {'text': "bloaz m'oc'h da betra"}
# Processed : common_voice_br_22694627.mp3 => {'text': "gall ran lakait en emgor benn dimerc'her"}
# Processed : common_voice_br_22694628.mp3 => {'text': 'en kichen ar bank'}
# Processed : common_voice_br_22694671.mp3 => {'text': 'rike se'}
# Processed : common_voice_br_22694682.mp3 => {'text': 'newelan ket al labous'}
# ...
# Processed : common_voice_br_18028151.mp3 => {'text': 'yen eo an amzer hirie'}
# Processed : common_voice_br_18028152.mp3 => {'text': "pellgomz a rign en drou diwezhatoc'h"}
# Processed : common_voice_br_18028154.mp3 => {'text': "ne fec'h ket"}
# Processed : common_voice_br_18028155.mp3 => {'text': 'aes e ober faziv'}
# Processed : common_voice_br_18028181.mp3 => {'text': 'piv out te'}
# Processed : common_voice_br_18028182.mp3 => {'text': 'ne vijen ket'}
# Processed : common_voice_br_18028184.mp3 => {'text': "ne fell ket deomp mont d'an arme"}
# Processed : common_voice_br_18028185.mp3 => {'text': "ken sod eo ma c'hi hag e hini"}
# Processed : common_voice_br_18028206.mp3 => {'text': 'amañ emaoneñ'}
# Processed : common_voice_br_18028207.mp3 => {'text': 'hoanonañ'}
# Processed : common_voice_br_18028208.mp3 => {'text': 'int zo bet karet'}
# Processed : common_voice_br_18028210.mp3 => {'text': 'ar gouarnamant ra chomohe bemellout en aferioù se'}
# Processed : common_voice_br_18028237.mp3 => {'text': 'sed eo al louarn o vont kuit'}
# Processed : common_voice_br_18028238.mp3 => {'text': 'daoustig eñ e teui'}
# Processed : common_voice_br_18028239.mp3 => {'text': 'ne soñj ket hin'}
# Processed : common_voice_br_18028251.mp3 => {'text': 'da werzhañ mañ'}
# Processed : common_voice_br_18028252.mp3 => {'text': 'enezh vriat'}
# Processed : common_voice_br_18028253.mp3 => {'text': 'petra eo pe dibus'}
# Processed : common_voice_br_18028254.mp3 => {'text': 'ne rannint grik'}
# Processed : common_voice_br_18028255.mp3 => {'text': 'kelene re'}
# Processed : common_voice_br_18028287.mp3 => {'text': 'pegement eo ar braouig o skouarn se'}
# Processed : common_voice_br_18028288.mp3 => {'text': 'mont a ra en heol da guzh pep noz'}
# Processed : common_voice_br_18028290.mp3 => {'text': 'evel kanta doa embregerezhoù all kemerit persennañ'}
# Processed : common_voice_br_18058446.mp3 => {'text': 'ha krouat e vo takado evit an dud war broad'}
# Processed : common_voice_br_18058447.mp3 => {'text': 'ha rit e kelenn anarzo'}
# Processed : common_voice_br_18058448.mp3 => {'text': 'piv wign'}
# Processed : common_voice_br_18058449.mp3 => {'text': "penbrema hoc'h eus"}
# Processed : common_voice_br_18058450.mp3 => {'text': "har poan anezhed d'o tro a c'hall d'ober ivez hon kemer perzh e c'houlzad ulu zarop gante"}
# Processed : common_voice_br_18058456.mp3 => {'text': 'u farzhal mann traken'}
# Processed : common_voice_br_18058457.mp3 => {'text': 'poent eomaont da skol'}
# Processed : common_voice_br_18058458.mp3 => {'text': 'un eil diwaññv'}
# Processed : common_voice_br_18058459.mp3 => {'text': "mont a ra d'ar skol"}
# Processed : common_voice_br_18058460.mp3 => {'text': "sur out e karc'het"}
# Processed : common_voice_br_18058466.mp3 => {'text': 'deulet eo'}
# Processed : common_voice_br_18058468.mp3 => {'text': 'skoet int bet kalet gant an enkadenn'}
# Processed : common_voice_br_18058469.mp3 => {'text': 'petra eo an dra se'}
# Processed : common_voice_br_18058470.mp3 => {'text': "kalz labour am eus ne'm eus ket amzer bremañ"}
# Processed : common_voice_br_18058481.mp3 => {'text': "mee a vez graet ac'hanomp"}
# Processed : common_voice_br_18058482.mp3 => {'text': "eveziadennoù diwar benn an digreskoù ha n'int ket reizhrak bihan ha pouezus evit ar re azi kemer anezhe"}
# Processed : common_voice_br_18058483.mp3 => {'text': 'lakat e voto en e dreid'}
# Processed : common_voice_br_18058484.mp3 => {'text': "roazhon holl zo laouen gant disoc'h a c'hogad"}
# Processed : common_voice_br_18058485.mp3 => {'text': "nec'hed oñ ivez"}
# Processed : common_voice_br_18058491.mp3 => {'text': 'petra o ober'}
# Processed : common_voice_br_18058492.mp3 => {'text': 'na vezit ket war evezh'}
# Processed : common_voice_br_18058494.mp3 => {'text': 'un hentenn sorsneg da ziskiñ kerneveurek evit mann'}
# Processed : common_voice_br_18058495.mp3 => {'text': 'istiklet e galleg'}
# Processed : common_voice_br_18058496.mp3 => {'text': 'unan daou tri'}
# Processed : common_voice_br_18058498.mp3 => {'text': 'ur gartenn eus kêr a garfin kaot'}
# Processed : common_voice_br_18058499.mp3 => {'text': 'em ouzon gour'}
# Processed : common_voice_br_18058500.mp3 => {'text': 'petra lakaat en ho paodr rotel'}
# Processed : common_voice_br_18504778.mp3 => {'text': "ganit e c'hoarive"}
# Processed : common_voice_br_18504779.mp3 => {'text': 'ret ae de mont bremañ'}
# Processed : common_voice_br_18504780.mp3 => {'text': 'hi e deus karet'}
# Processed : common_voice_br_18504782.mp3 => {'text': 'met petra eo an dioren padus dre just'}
# Processed : common_voice_br_18504783.mp3 => {'text': 'setu te'}
# Processed : common_voice_br_18504784.mp3 => {'text': 'kadorioù all zo amañ'}
# Processed : common_voice_br_18504785.mp3 => {'text': 'siwerniet on'}
# Processed : common_voice_br_18504786.mp3 => {'text': 'in ho deus bet karet'}
# Processed : common_voice_br_18504793.mp3 => {'text': 'mev e on'}
# Processed : common_voice_br_18504794.mp3 => {'text': 'peseurt boueda gorvit ar gwelañ'}
# Processed : common_voice_br_18504795.mp3 => {'text': 'unan ha daoul ugent'}
# Processed : common_voice_br_18504796.mp3 => {'text': 'hor chom sini'}
# Processed : common_voice_br_18504797.mp3 => {'text': 'ul loa koad'}
# Processed : common_voice_br_18504812.mp3 => {'text': "pell a oalc'h emoaint bremañ"}
# Processed : common_voice_br_18504813.mp3 => {'text': 'gwest  oa da dremen hep debiñ tri dewesvad'}
# Processed : common_voice_br_18504816.mp3 => {'text': 'petr emaint'}
# Processed : common_voice_br_18504817.mp3 => {'text': 'ur pic hol taroù'}
# Processed : common_voice_br_18141713.mp3 => {'text': "pelec'h o peus greit an naoudegezh ganti"}
# Processed : common_voice_br_18141716.mp3 => {'text': 'mui o ti un o benn a oest e wa heur'}
# Processed : common_voice_br_18141723.mp3 => {'text': "sic'henaint"}
# Processed : common_voice_br_18141724.mp3 => {'text': 'per'}
# Processed : common_voice_br_18141725.mp3 => {'text': "kemeret a c'hachedoùu mañ pad tri dezhe"}
# Processed : common_voice_br_18141726.mp3 => {'text': 'gwashad amzer'}
# Processed : common_voice_br_18141737.mp3 => {'text': "o da 'hoarn"}
# Processed : common_voice_br_18141739.mp3 => {'text': 'lanet ur furm skrid mañ'}
# Processed : common_voice_br_18141741.mp3 => {'text': 'ur lizher arnien'}
# Processed : common_voice_br_18141747.mp3 => {'text': 'ha kampenn e yarzh en dro da añ'}
# Processed : common_voice_br_18141748.mp3 => {'text': 'petra nevez evit un doristed'}
# Processed : common_voice_br_18141749.mp3 => {'text': 'peseurt niveren pellgomz eo'}
# Processed : common_voice_br_18141751.mp3 => {'text': 'eizhint kuit'}
# Processed : common_voice_br_18141776.mp3 => {'text': "hourmetr ha 'hante kant santimetr"}
# Processed : common_voice_br_18141779.mp3 => {'text': 'gomzañ ket saozneg flour'}
# Processed : common_voice_br_18141780.mp3 => {'text': 'tri a vugale'}
# Processed : common_voice_br_18141782.mp3 => {'text': 'ur raned e glevenn'}
# Processed : common_voice_br_18141783.mp3 => {'text': 'ha mar e pouezusañ an abadenn'}
# Processed : common_voice_br_18141784.mp3 => {'text': 'biont em boa hi dizaliet'}
# Processed : common_voice_br_18141785.mp3 => {'text': 'noargnen'}
# Processed : common_voice_br_18141786.mp3 => {'text': "kare'm eus bet"}
# Processed : common_voice_br_18141798.mp3 => {'text': 'he pariz mañ e chom e frañs'}
# Processed : common_voice_br_18141800.mp3 => {'text': 'hag amzer peus de lenn er gazetenn daouze mintin'}
# Processed : common_voice_br_18141801.mp3 => {'text': 'drou zo inan eo bet kollet en dilennadegoù gant distrollat'}
# Processed : common_voice_br_18141804.mp3 => {'text': "ken aneoae dec'h ne ouien ket a yaeloù"}
# Processed : common_voice_br_18141805.mp3 => {'text': 'kaour ha dezi zo blaz mat gantañ'}
# Processed : common_voice_br_18141806.mp3 => {'text': 'ur re hont'}
# Processed : common_voice_br_18141812.mp3 => {'text': 'niveren ar leti hilton a garfen kaou eo mar plij'}
# Processed : common_voice_br_18141813.mp3 => {'text': 'heañv o lennas'}
# Processed : common_voice_br_18141814.mp3 => {'text': 'demb e ar levrioù se'}
# Processed : common_voice_br_18141822.mp3 => {'text': 'yent tre eo'}
# Processed : common_voice_br_18141823.mp3 => {'text': 'per vot'}
# Processed : common_voice_br_18141824.mp3 => {'text': 'hun hanaver niverel petra eo'}
# Processed : common_voice_br_18141825.mp3 => {'text': 'oan daol'}
# Processed : common_voice_br_18141832.mp3 => {'text': 'ur follennoù hirañ'}
# Processed : common_voice_br_18141833.mp3 => {'text': 'hantek anein'}
# Processed : common_voice_br_18141834.mp3 => {'text': "sac'h gwen se"}
# Processed : common_voice_br_18141835.mp3 => {'text': "da bet eur c'hordiunat"}
# Processed : common_voice_br_18141842.mp3 => {'text': 'noeran netra'}
# Processed : common_voice_br_18141843.mp3 => {'text': 'koust ez e dwe lavaret eñ vije dezit'}
# Processed : common_voice_br_18141844.mp3 => {'text': 'skoet on ebeut'}
# Processed : common_voice_br_18141845.mp3 => {'text': 'ur pemp sportour euzh vras'}
# Processed : common_voice_br_18141846.mp3 => {'text': "peseurt d'arzac'h e"}
# Processed : common_voice_br_18141852.mp3 => {'text': 'ur vollennad souben zo genezhi'}
# Processed : common_voice_br_18141854.mp3 => {'text': "da bi emañ da c'hoari"}
# Processed : common_voice_br_18141855.mp3 => {'text': 'heñz eo niint gwellañ'}
# Processed : common_voice_br_18141856.mp3 => {'text': 'di eur'}
# Processed : common_voice_br_18141857.mp3 => {'text': 'ret eo dezhñt labrat'}
# Processed : common_voice_br_18141861.mp3 => {'text': 'suchtamañ'}
# Processed : common_voice_br_18141872.mp3 => {'text': 'gwi an bugel'}
# Processed : common_voice_br_18141875.mp3 => {'text': 'pimet eo emañ teu viha mi'}
# Processed : common_voice_br_18141877.mp3 => {'text': 'en e velep doare a galane eo bet dozet en noz ez'}
# Processed : common_voice_br_18141879.mp3 => {'text': 'an daol'}
# Processed : common_voice_br_18141880.mp3 => {'text': 'ket a raint'}
# Processed : common_voice_br_18141888.mp3 => {'text': "o c'hi biann ha tregont"}
# Processed : common_voice_br_18141890.mp3 => {'text': 'in on kaozh'}
# Processed : common_voice_br_18141891.mp3 => {'text': 'dek ten bennaket zo emp buro'}
# Processed : common_voice_br_18141898.mp3 => {'text': "poneroc'h 'houaz evit a soñjenn"}
# Processed : common_voice_br_18141899.mp3 => {'text': 'pevar olifant ruz ha tregont'}
# Processed : common_voice_br_18141900.mp3 => {'text': 'boe ma on yar en dro'}
# Processed : common_voice_br_34504731.mp3 => {'text': "n em blec'h ebeut"}
# Processed : common_voice_br_34504732.mp3 => {'text': "monet o ran ar yann d'er gir"}
# Processed : common_voice_br_34504734.mp3 => {'text': 'e heuilh'}
# Processed : common_voice_br_34504749.mp3 => {'text': 'goulenn a ra e pee eo'}
# Processed : common_voice_br_34504750.mp3 => {'text': 'ne glemmint ket grint'}
# Processed : common_voice_br_34504751.mp3 => {'text': "ne oec'h ket eon amañ"}
# Processed : common_voice_br_34504752.mp3 => {'text': "n'e et gwelet se biskoù arcwelc'h"}
# Processed : common_voice_br_34504753.mp3 => {'text': "pijec'h gwellzarvout kar zo beut"}
# Processed : common_voice_br_34504765.mp3 => {'text': 'pegen lies e fent gwelet'}
# Processed : common_voice_br_34504766.mp3 => {'text': 'nebeuet eus ou dezit daze ben inerh'}
# Processed : common_voice_br_34504767.mp3 => {'text': 'daou legad blim'}
# Processed : common_voice_br_34504768.mp3 => {'text': 'ti gari'}
# Processed : common_voice_br_34504780.mp3 => {'text': 'ha ouannt e euaes da vereñ ur rolloù kasuriont berzht bezhmañ'}
# Processed : common_voice_br_34504783.mp3 => {'text': 'mat he kren nev'}
# Processed : common_voice_br_34504784.mp3 => {'text': 'di wezr goude krestiñ'}
# Processed : common_voice_br_34504804.mp3 => {'text': "gouilet eo ret pelec'h eeush ur stal e wec'h serviet enoù"}
# Processed : common_voice_br_34504805.mp3 => {'text': "n'en de che doujet d'ur hivlennoù"}
# Processed : common_voice_br_34504806.mp3 => {'text': "macr' gra"}
# Processed : common_voice_br_34504807.mp3 => {'text': 'laezh a gar amañ gant ne vo ket ar hent'}
# Processed : common_voice_br_34504808.mp3 => {'text': 'fari piv eo'}
# Processed : common_voice_br_34504814.mp3 => {'text': 'nint da lennv'}
# Processed : common_voice_br_34504815.mp3 => {'text': "un dra a c'hall se"}
# Processed : common_voice_br_34504817.mp3 => {'text': 'bremañ e welanoñ'}
# Processed : common_voice_br_34504818.mp3 => {'text': "penaos e keiet d'ap benn"}
# Processed : common_voice_br_34504824.mp3 => {'text': 'ne gompren ket buhe an dud'}
# Processed : common_voice_br_34504825.mp3 => {'text': 'kant nav mil ved hab poegen'}
# Processed : common_voice_br_34504826.mp3 => {'text': 'deit eo amañ e unañ'}
# Processed : common_voice_br_34504827.mp3 => {'text': 'feunestr hon ti'}
# Processed : common_voice_br_34504828.mp3 => {'text': 'treiñ faout'}
# Processed : common_voice_br_34504835.mp3 => {'text': "gouannt a maes da fermin ur c'har"}
# Processed : common_voice_br_34504836.mp3 => {'text': 'eñvel eo m eus pernet ha de breud emez wenañ anezhe'}
# Processed : common_voice_br_34504837.mp3 => {'text': "ur c'hantelioù pouizusañ"}
# Processed : common_voice_br_34504838.mp3 => {'text': "a benn pegeit emañ ur c'harr boutign kentañ evit filhadelfia"}
# Processed : common_voice_br_34504841.mp3 => {'text': "chwec'h tre wenn"}
# Processed : common_voice_br_34504842.mp3 => {'text': 'ur pretiezhoù nepell'}
# Processed : common_voice_br_34504844.mp3 => {'text': 'diz geneiñ mar plij'}
# Processed : common_voice_br_34504845.mp3 => {'text': "oc'h eus sent"}
# Processed : common_voice_br_34504867.mp3 => {'text': "pevar de e vez shec'hvet ouzhstal"}
# Processed : common_voice_br_34504868.mp3 => {'text': 'komz zo ret ospagnoleg'}
# Processed : common_voice_br_34504891.mp3 => {'text': 'ur brezidantez'}
# Processed : common_voice_br_34504892.mp3 => {'text': 'a benn pegorzh evet kuit'}
# Processed : common_voice_br_34504893.mp3 => {'text': 'karout a ran m em bro'}
# Processed : common_voice_br_34504900.mp3 => {'text': 'chwizh us eo un dra se'}
# Processed : common_voice_br_34504901.mp3 => {'text': 'ur paz zo ganein'}
# Processed : common_voice_br_34504903.mp3 => {'text': "evit un dezenn n'ote nedez ar meudiha taer"}
# Processed : common_voice_br_34504906.mp3 => {'text': 'penaos e hi'}
# Processed : common_voice_br_34504912.mp3 => {'text': 'mem brer'}
# Processed : common_voice_br_34504917.mp3 => {'text': "da cheu netra marc'hadmatoc'h"}
# Processed : common_voice_br_34504918.mp3 => {'text': 'da bet er umgavam'}
# Processed : common_voice_br_34504920.mp3 => {'text': 'naou'}
# Processed : common_voice_br_34504921.mp3 => {'text': 'añrollet ur listen no'}
# Processed : common_voice_br_34504942.mp3 => {'text': 'penaos ma beut kaset un labour diout benn'}
# Processed : common_voice_br_34504943.mp3 => {'text': 'mam eus daou diked'}
# Processed : common_voice_br_34504944.mp3 => {'text': 'he dad'}
# Processed : common_voice_br_34504949.mp3 => {'text': 'dei dont asagema famiilh'}
# Processed : common_voice_br_34504951.mp3 => {'text': 'pemp olifant ha tourgont'}
# Processed : common_voice_br_36762498.mp3 => {'text': 'poent nu mont ed cuid'}
# Processed : common_voice_br_36762500.mp3 => {'text': 'hounheñ vras'}
# Processed : common_voice_br_36762501.mp3 => {'text': "ha kar oc'h da nevtru moañ"}
# Processed : common_voice_br_36762502.mp3 => {'text': 'net ce stang an dud'}
# Processed : common_voice_br_17987917.mp3 => {'text': 'an iliz kaerañ eus ar vro'}
# Processed : common_voice_br_17988411.mp3 => {'text': 'graet en doa al labour e unan'}
# Processed : common_voice_br_17994057.mp3 => {'text': "ar memes tra a vo goulennet diganeoc'h"}
# Processed : common_voice_br_17995860.mp3 => {'text': 'alies em galv da zont da reiñ dorn dezhañ'}
# Processed : common_voice_br_17996179.mp3 => {'text': 'me te eñhi'}
# Processed : common_voice_br_17998028.mp3 => {'text': "ar c'hartan ruz nevez flamm maon"}
# Processed : common_voice_br_17999626.mp3 => {'text': "gwelet a rin anezhañ dimerc'her kentañ"}
# /tmp/ipykernel_36/2615440035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Transcription"] = df.apply(get_transcription, axis=1)

# %%
df
# Out:
#                               path  \
# 0     common_voice_br_43418986.mp3
# 1     common_voice_br_18382821.mp3
# 2     common_voice_br_17977507.mp3
# 3     common_voice_br_41622444.mp3
# 4     common_voice_br_19737696.mp3
# ...                            ...
# 2860  common_voice_br_17994057.mp3
# 2861  common_voice_br_17995860.mp3
# 2862  common_voice_br_17996179.mp3
# 2863  common_voice_br_17998028.mp3
# 2864  common_voice_br_17999626.mp3
#
#                                         sentence gender sentence_domain  age  \
# 0                     Kanañ a raent en hent don.    NaN         general  NaN
# 1                       digor e vez da Verc'her.    NaN             NaN  NaN
# 2        Re nebeut a zo deuet da reiñ dorn dimp.    NaN             NaN  NaN
# 3                  Kemerit ho tafar hag azezit !    NaN             NaN  NaN
# 4                                   Be'h dezhi !    NaN             NaN  NaN
# ...                                          ...    ...             ...  ...
# 2860      Ar memes tra a vo gulennet diganeoc'h.    NaN             NaN  NaN
# 2861  Alies em galv da zont da reiñ dorn dezhañ.    NaN             NaN  NaN
# 2862                              Me/ Te. Eñ/Hi.    NaN             NaN  NaN
# 2863         Ar c'harr-tan ruz nevez-flamm-hont.    NaN             NaN  NaN
# 2864     gwelet a rin anezhañ dimerc'her kentañ.    NaN             NaN  NaN
#
#      accents                                      Transcription
# 0        NaN                {'text': 'kanañ a raint en en don'}
# 1        NaN                   {'text': 'digor vez da vec'her'}
# 2        NaN  {'text': 're nebeut a zo dibet da rein d'an de...
# 3        NaN          {'text': 'kemerit ho tafoc'h hag azezit'}
# 4        NaN                      {'text': 'bec'hchwa davoued'}
# ...      ...                                                ...
# 2860     NaN  {'text': 'ar memes tra a vo goulennet diganeoc...
# 2861     NaN  {'text': 'alies em galv da zont da reiñ dorn d...
# 2862     NaN                             {'text': 'me te eñhi'}
# 2863     NaN       {'text': 'ar c'hartan ruz nevez flamm maon'}
# 2864     NaN  {'text': 'gwelet a rin anezhañ dimerc'her kent...
#
# [2865 rows x 7 columns]

# %%
df["Transcription"] = df["Transcription"].apply(lambda x: x['text'] if isinstance(x, dict) and 'text' in x else x)

# %%
df
# Out:
#                               path  \
# 0     common_voice_br_43418986.mp3
# 1     common_voice_br_18382821.mp3
# 2     common_voice_br_17977507.mp3
# 3     common_voice_br_41622444.mp3
# 4     common_voice_br_19737696.mp3
# ...                            ...
# 2860  common_voice_br_17994057.mp3
# 2861  common_voice_br_17995860.mp3
# 2862  common_voice_br_17996179.mp3
# 2863  common_voice_br_17998028.mp3
# 2864  common_voice_br_17999626.mp3
#
#                                         sentence gender sentence_domain  age  \
# 0                     Kanañ a raent en hent don.    NaN         general  NaN
# 1                       digor e vez da Verc'her.    NaN             NaN  NaN
# 2        Re nebeut a zo deuet da reiñ dorn dimp.    NaN             NaN  NaN
# 3                  Kemerit ho tafar hag azezit !    NaN             NaN  NaN
# 4                                   Be'h dezhi !    NaN             NaN  NaN
# ...                                          ...    ...             ...  ...
# 2860      Ar memes tra a vo gulennet diganeoc'h.    NaN             NaN  NaN
# 2861  Alies em galv da zont da reiñ dorn dezhañ.    NaN             NaN  NaN
# 2862                              Me/ Te. Eñ/Hi.    NaN             NaN  NaN
# 2863         Ar c'harr-tan ruz nevez-flamm-hont.    NaN             NaN  NaN
# 2864     gwelet a rin anezhañ dimerc'her kentañ.    NaN             NaN  NaN
#
#      accents                              Transcription
# 0        NaN                    kanañ a raint en en don
# 1        NaN                       digor vez da vec'her
# 2        NaN  re nebeut a zo dibet da rein d'an deomper
# 3        NaN              kemerit ho tafoc'h hag azezit
# 4        NaN                          bec'hchwa davoued
# ...      ...                                        ...
# 2860     NaN     ar memes tra a vo goulennet diganeoc'h
# 2861     NaN  alies em galv da zont da reiñ dorn dezhañ
# 2862     NaN                                 me te eñhi
# 2863     NaN           ar c'hartan ruz nevez flamm maon
# 2864     NaN     gwelet a rin anezhañ dimerc'her kentañ
#
# [2865 rows x 7 columns]

# %%
ground_truth_path="/kaggle/input/test-tsv/test.tsv"

ground_truth_dict = load_ground_truth_dict_commonvoice(ground_truth_path)

# %%
from filter_char import filter_out_chars
from normalizer import normalize_sentence
from utils import pre_process


def process_br_text(br):
    PUNCTUATION = '<>.?!,;:«»“”"()[]/…–—•'
    br = filter_out_chars(br, PUNCTUATION + '*')
    br = normalize_sentence(br, autocorrect=True)
    br = pre_process(br).replace('-', ' ').lower()
    return br

# %%
df['sentence_processed'] = df['sentence'].apply(process_br_text)

# %%
from jiwer import wer, cer

# Compute WER and CER for each row
df['wer'] = df.apply(lambda row: wer(row['sentence_processed'], row['Transcription']), axis=1)
df['cer'] = df.apply(lambda row: cer(row['sentence_processed'], row['Transcription']), axis=1)

# %%
df = df[['sentence', 'sentence_processed', 'Transcription', 'wer', 'cer','gender','sentence_domain','age','accents']]
df
# Out:
#                                         sentence  \
# 0                     Kanañ a raent en hent don.
# 1                       digor e vez da Verc'her.
# 2        Re nebeut a zo deuet da reiñ dorn dimp.
# 3                  Kemerit ho tafar hag azezit !
# 4                                   Be'h dezhi !
# ...                                          ...
# 2860      Ar memes tra a vo gulennet diganeoc'h.
# 2861  Alies em galv da zont da reiñ dorn dezhañ.
# 2862                              Me/ Te. Eñ/Hi.
# 2863         Ar c'harr-tan ruz nevez-flamm-hont.
# 2864     gwelet a rin anezhañ dimerc'her kentañ.
#
#                              sentence_processed  \
# 0                     kanañ a raent en hent don
# 1                       digor e vez da verc'her
# 2       re nebeut a zo deuet da reiñ dorn deomp
# 3                   kemerit ho tafar hag azezit
# 4                                    be'h dezhi
# ...                                         ...
# 2860     ar memes tra a vo goulennet diganeoc'h
# 2861  alies em galv da zont da reiñ dorn dezhañ
# 2862                                 me te eñhi
# 2863         ar c'harr tan ruz nevez flamm hont
# 2864     gwelet a rin anezhañ dimerc'her kentañ
#
#                                   Transcription       wer       cer gender  \
# 0                       kanañ a raint en en don  0.333333  0.120000    NaN
# 1                          digor vez da vec'her  0.400000  0.130435    NaN
# 2     re nebeut a zo dibet da rein d'an deomper  0.444444  0.179487    NaN
# 3                 kemerit ho tafoc'h hag azezit  0.200000  0.148148    NaN
# 4                             bec'hchwa davoued  1.000000  1.100000    NaN
# ...                                         ...       ...       ...    ...
# 2860     ar memes tra a vo goulennet diganeoc'h  0.000000  0.000000    NaN
# 2861  alies em galv da zont da reiñ dorn dezhañ  0.000000  0.000000    NaN
# 2862                                 me te eñhi  0.000000  0.000000    NaN
# 2863           ar c'hartan ruz nevez flamm maon  0.428571  0.147059    NaN
# 2864     gwelet a rin anezhañ dimerc'her kentañ  0.000000  0.000000    NaN
#
#      sentence_domain  age accents
# 0            general  NaN     NaN
# 1                NaN  NaN     NaN
# 2                NaN  NaN     NaN
# 3                NaN  NaN     NaN
# 4                NaN  NaN     NaN
# ...              ...  ...     ...
# 2860             NaN  NaN     NaN
# 2861             NaN  NaN     NaN
# 2862             NaN  NaN     NaN
# 2863             NaN  NaN     NaN
# 2864             NaN  NaN     NaN
#
# [2865 rows x 9 columns]

# %%
print(df['gender'].value_counts(dropna=False))
print("--------------------------------")

# Filter for male voice audio
df_male = df[df['gender'].str.startswith('male_masculine', na=False)]

avg_male = df_male[['wer', 'cer']].mean().round(4)


# Filter for female voice audio
df_female = df[df['gender'].str.startswith('female_feminine', na=False)]

avg_female = df_female[['wer', 'cer']].mean().round(4)

print("Evaluation for Female audio files :")
print(f"WER: {avg_female['wer']}")
print(f"CER: {avg_female['cer']}\n")

print("Evaluation for Male audio files :")
print(f"WER: {avg_male['wer']}")
print(f"CER: {avg_male['cer']}\n")
# Out:
# gender
# NaN                1875
# male_masculine      760
# female_feminine     230
# Name: count, dtype: int64
# --------------------------------
# Evaluation for Female audio files :
# WER: 0.3388
# CER: 0.12
#
# Evaluation for Male audio files :
# WER: 0.4591
# CER: 0.1695

# %%
print(df['sentence_domain'].value_counts(dropna=False))
# Out:
# sentence_domain
# NaN                       2583
# general                    275
# history_law_government       2
# general,general              1
# media_entertainment          1
# service_retail               1
# technology_robotics          1
# healthcare                   1
# Name: count, dtype: int64

# %%
print(df['age'].value_counts(dropna=False))
print("--------------------------------")

# Filter for twenties voice audio
df_twenties = df[df['age'].str.startswith('twenties', na=False)]
avg_twenties = df_twenties[['wer', 'cer']].mean().round(4)

# Filter for thirties voice audio
df_thirties = df[df['age'].str.startswith('thirties', na=False)]
avg_thirties = df_thirties[['wer', 'cer']].mean().round(4)

# Filter for fourties voice audio
df_fourties = df[df['age'].str.startswith('fourties', na=False)]
avg_fourties = df_fourties[['wer', 'cer']].mean().round(4)

# Filter for fifties voice audio
df_fifties = df[df['age'].str.startswith('fifties', na=False)]
avg_fifties = df_fifties[['wer', 'cer']].mean().round(4)

# Filter for sixties voice audio
df_sixties = df[df['age'].str.startswith('sixties', na=False)]
avg_sixties = df_sixties[['wer', 'cer']].mean().round(4)

print("Evaluation for Twenties audio files :")
print(f"WER: {avg_twenties['wer']}")
print(f"CER: {avg_twenties['cer']}\n")

print("Evaluation for Thirties audio files :")
print(f"WER: {avg_thirties['wer']}")
print(f"CER: {avg_thirties['cer']}\n")

print("Evaluation for Fourties audio files :")
print(f"WER: {avg_fourties['wer']}")
print(f"CER: {avg_fourties['cer']}\n")

print("Evaluation for Fifties audio files :")
print(f"WER: {avg_fifties['wer']}")
print(f"CER: {avg_fifties['cer']}\n")

print("Evaluation for Sixties audio files :")
print(f"WER: {avg_sixties['wer']}")
print(f"CER: {avg_sixties['cer']}\n")
# Out:
# age
# NaN          1628
# twenties      600
# thirties      206
# fourties      140
# fifties       137
# sixties       105
# seventies      49
# Name: count, dtype: int64
# --------------------------------
# Evaluation for Twenties audio files :
# WER: 0.4273
# CER: 0.1548
#
# Evaluation for Thirties audio files :
# WER: 0.3287
# CER: 0.1127
#
# Evaluation for Fourties audio files :
# WER: 0.5673
# CER: 0.2108
#
# Evaluation for Fifties audio files :
# WER: 0.4029
# CER: 0.1388
#
# Evaluation for Sixties audio files :
# WER: 0.4314
# CER: 0.1603

# %%
print(df['accents'].value_counts(dropna=False))
print("--------------------------------")
# Filter for Leoneg voice audio
df_Leoneg = df[df['accents'].str.startswith('Leoneg', na=False)]
avg_Leoneg = df_Leoneg[['wer', 'cer']].mean().round(4)

df_Kerneveg = df[df['accents'].str.startswith('Kerneveg', na=False)]
avg_Kerneveg = df_Kerneveg[['wer', 'cer']].mean().round(4)

df_Gwenedeg = df[df['accents'].str.startswith('Gwenedeg', na=False)]
avg_Gwenedeg = df_Gwenedeg[['wer', 'cer']].mean().round(4)

print("Evaluation for Leoneg audio files :")
print(f"WER: {avg_Leoneg['wer']}")
print(f"CER: {avg_Leoneg['cer']}\n")

print("Evaluation for Kerneveg audio files :")
print(f"WER: {avg_Kerneveg['wer']}")
print(f"CER: {avg_Kerneveg['cer']}\n")

print("Evaluation for Gwenedeg audio files :")
print(f"WER: {avg_Gwenedeg['wer']}")
print(f"CER: {avg_Gwenedeg['cer']}\n")
# Out:
# accents
# NaN                      2399
# Leoneg                    215
# Kerneveg                  136
# Gwenedeg                   88
# Brezhoneg Breizh-Uhel      10
# Gwenedeg,Kerneveg           9
# Standard                    5
# Tregerieg                   3
# Name: count, dtype: int64
# --------------------------------
# Evaluation for Leoneg audio files :
# WER: 0.3932
# CER: 0.1363
#
# Evaluation for Kerneveg audio files :
# WER: 0.4223
# CER: 0.1409
#
# Evaluation for Gwenedeg audio files :
# WER: 0.6298
# CER: 0.2847

# %%
# Assuming 'wer' and 'cer' columns exist
average_wer = df['wer'].mean()
average_cer = df['cer'].mean()

# Optional: round them
average_wer = round(average_wer, 2)
average_cer = round(average_cer, 2)

print(f"Overall Average WER: {average_wer}")
print(f"Overall Average CER: {average_cer}")
# Out:
# Overall Average WER: 0.43
# Overall Average CER: 0.16
